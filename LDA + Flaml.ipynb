# %% [markdown]
# # FLAML to tune parameters with LDA
#
# MSc in Statistical Science\
# University of Oxford\
# Group-assessed practical\
# HT 2024

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, zero_one_loss, make_scorer, classification_report
from sklearn.preprocessing import StandardScaler, LabelEncoder
from flaml import AutoML
from flaml.ml import sklearn_metric_loss_score
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %% [markdown]
# ## Load dataset

# %%
# Load the training data and the test inputs
X_train = pd.read_csv('X_train.csv', index_col = 0, header=[0, 1, 2]) # inputs of the training set
y_train = pd.read_csv('y_train.csv', index_col=0).squeeze('columns').to_numpy() # outputs of the training set
X_test = pd.read_csv('X_test.csv', index_col = 0, header=[0, 1, 2]) # inputs of the test set

# %%
# X_train is a 6,000 * 518 dataframe. 
# Entries (i,j) correspond to the j'th dimension of the observation i
X_train
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# Id
# 0            -0.266585 -0.984668 -0.729823 -0.895122  2.138628  0.935209
# 1            -0.180061  0.260884 -0.069373  0.208734 -0.078855 -0.577818
# 2            -0.692900  0.356662  0.062617  0.248280  3.470037  0.166613
# 3             0.243339  0.214182 -0.049026  1.456255 -0.360826 -0.875256
# 4            -0.968576  0.309255  0.223164  0.160960  0.919838 -0.111985
# ...                ...       ...       ...       ...       ...       ...
# 5995          0.503490 -0.540720 -0.690117 -0.107338 -0.647856 -0.681969
# 5996         -0.600597  0.406386 -0.748409 -0.316157 -0.507428 -0.054214
# 5997         -1.014298 -0.950744  0.618304  0.204298 -0.788411 -0.794254
# 5998         -0.002938  0.646034 -0.732819  1.205990 -0.898733 -0.684953
# 5999         -0.881917 -0.615638  0.891155  4.850262 -0.349280 -1.010980
#
# feature                                             ...   tonnetz            \
# statistics                                          ...       std
# number            07        08        09        10  ...        04        05
# Id                                                  ...
# 0           0.104089 -0.698659 -0.736408 -0.334376  ...  0.065003  0.016522
# 1           0.583788  0.143781  0.291556  0.007314  ...  0.087692  0.016355
# 2           0.823874  0.181112  0.551939  0.357985  ...  0.132387  0.025847
# 3          -0.770200  0.315500  0.789956  0.448319  ...  0.071478  0.019166
# 4          -1.012521 -0.665692 -0.316646 -0.264381  ...  0.106220  0.023536
# ...              ...       ...       ...       ...  ...       ...       ...
# 5995       -0.246245 -0.546552  0.062783  0.070393  ...  0.084929  0.017250
# 5996       -0.476804 -0.373120 -0.930158 -1.080690  ...  0.075407  0.014998
# 5997       -0.586847  0.099172 -0.313476 -0.523417  ...  0.138591  0.024969
# 5998        0.134642 -0.374792 -0.019524 -1.016032  ...  0.137695  0.030371
# 5999       -0.577905 -0.046604 -0.828026 -0.457468  ...  0.175120  0.039703
#
# feature                      zcr                                          \
# statistics              kurtosis       max      mean    median       min
# number            06          01        01        01        01        01
# Id
# 0           0.015776    5.743597  0.307617  0.051370  0.042480  0.002441
# 1           0.016605   64.870987  0.812988  0.082784  0.069824  0.003906
# 2           0.023922   34.251705  0.850098  0.058200  0.036621  0.010254
# 3           0.025535    1.364990  0.342285  0.081713  0.075195  0.000000
# 4           0.019742    3.589230  0.322266  0.073736  0.069336  0.004395
# ...              ...         ...       ...       ...       ...       ...
# 5995        0.020335    4.868783  0.668945  0.076452  0.044434  0.001465
# 5996        0.020683    7.893681  0.584961  0.076210  0.048340  0.000000
# 5997        0.023658   27.257378  0.373047  0.042598  0.037598  0.000000
# 5998        0.029970  431.200500  0.384277  0.025731  0.025391  0.008301
# 5999        0.025094   13.567758  0.233398  0.047689  0.044922  0.015625
#
# feature
# statistics       skew       std
# number             01        01
# Id
# 0            1.976972  0.034533
# 1            7.374503  0.074870
# 2            5.927942  0.117603
# 3            1.100437  0.041754
# 4            1.210593  0.036459
# ...               ...       ...
# 5995         2.045856  0.084214
# 5996         2.561808  0.073010
# 5997         3.778109  0.027813
# 5998        10.260160  0.006870
# 5999         2.553229  0.018049
#
# [6000 rows x 518 columns]

# %%
#y_train contains the true class:  Electronic, Experimental, Folk, Hip-Hop, Instrumental, International, Pop or Rock
y_train
# Out:
# array(['Electronic', 'Rock', 'Instrumental', ..., 'Pop', 'Instrumental',
#        'Instrumental'], dtype=object)

# %%
# X_test is the array of test inputs, of the same format as X_train. The objective is to predict the class (Electronic, Experimental, Folk, Hip-Hop, Instrumental, International, Pop or Rock) of the output
X_test
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# Id
# 0             3.974762  4.354650  3.394523  0.033462  5.611623  2.592655
# 1             0.033636 -0.139950  0.678688 -0.553824 -0.165293  0.370275
# 2             0.044094  4.285359  0.977213  3.240997  0.400350  1.026224
# 3            -0.425218  0.793007  0.509624 -0.967103 -1.432252 -0.900761
# 4            -1.120238 -0.503659  0.303515 -0.596549 -0.716761 -0.874363
# ...                ...       ...       ...       ...       ...       ...
# 1995         -0.166039 -0.660406 -0.955245 -0.689303 -0.916851 -0.136661
# 1996          2.010343  0.344572  2.738141  1.238262  2.815471  0.689118
# 1997         -0.869148 -0.600280  0.105814  0.553810 -0.839182 -0.706434
# 1998         -0.854251 -0.804227  1.347275 -0.748155 -0.408385 -0.909165
# 1999          0.929528  0.922116  1.074849  0.431512  0.040441 -0.361733
#
# feature                                             ...   tonnetz            \
# statistics                                          ...       std
# number            07        08        09        10  ...        04        05
# Id                                                  ...
# 0           3.041094  2.815378  3.954026  2.365586  ...  0.052970  0.013487
# 1          -0.314710 -0.368706 -0.437181 -0.441662  ...  0.093105  0.022865
# 2           0.772464  0.807625  1.942534  1.938970  ...  0.081955  0.017371
# 3          -0.501279 -0.855886 -0.556825  7.404243  ...  0.098877  0.019089
# 4          -0.708101 -0.642351 -0.327327 -0.342220  ...  0.102545  0.023823
# ...              ...       ...       ...       ...  ...       ...       ...
# 1995       -0.367279 -1.135291 -1.174082 -0.609749  ...  0.060857  0.022777
# 1996        4.040531  2.749969  2.658481  4.763800  ...  0.050589  0.015169
# 1997       -0.360566  0.053638 -0.791513 -0.669329  ...  0.079556  0.025229
# 1998       -0.870467 -0.077660 -0.538250 -0.108390  ...  0.147899  0.023989
# 1999        0.371801  0.470401 -0.566806  0.082485  ...  0.119940  0.023605
#
# feature                     zcr                                          \
# statistics             kurtosis       max      mean    median       min
# number            06         01        01        01        01        01
# Id
# 0           0.022031  70.844788  0.671387  0.035129  0.026367  0.010254
# 1           0.028800  18.427612  0.538574  0.055975  0.039062  0.000000
# 2           0.016673  38.401405  0.405762  0.030685  0.028809  0.002930
# 3           0.016183   4.129582  0.252441  0.037955  0.024902  0.000000
# 4           0.025166  16.758356  0.380371  0.027851  0.019043  0.000000
# ...              ...        ...       ...       ...       ...       ...
# 1995        0.017722   8.467750  0.444824  0.055770  0.039062  0.001465
# 1996        0.013096  -0.649581  0.357422  0.126850  0.120117  0.000000
# 1997        0.026858   1.563682  0.152344  0.039138  0.035156  0.002441
# 1998        0.027429  22.050222  0.319824  0.032715  0.028809  0.000000
# 1999        0.024036   2.444547  0.256836  0.047209  0.041016  0.002441
#
# feature
# statistics      skew       std
# number            01        01
# Id
# 0           8.394708  0.067026
# 1           3.638194  0.053879
# 2           2.620369  0.016835
# 3           1.898847  0.034382
# 4           3.244483  0.027128
# ...              ...       ...
# 1995        2.520271  0.056601
# 1996        0.234551  0.055476
# 1997        1.084503  0.020284
# 1998        3.429668  0.022654
# 1999        1.266626  0.030202
#
# [2000 rows x 518 columns]

# %%
X = X_train
y = y_train
# Assuming you have X_train and y_train defined earlier

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# %%
# Scale the features using StandardScaler
scalerx = StandardScaler()
X_train = scalerx.fit_transform(X_train)
X_val = scalerx.transform(X_val)

# Assuming y is your target variable
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)

# %%
# Apply LDA for dimensionality reduction
lda = LinearDiscriminantAnalysis(n_components=7)  # You can choose the number of components
X_train_lda = lda.fit_transform(X_train, y_train)
X_val_lda = lda.transform(X_val)

# %% [markdown]
# ## Classification with AutoML and prediction on the test set

# %%
# Initialize an AutoML instance
automl = AutoML()

# Specify automl goal and constraint
automl_settings = {
    "time_budget": 600,  # in seconds
    "metric": 'accuracy',
    "task": 'classification',
    "log_file_name": "songlda-600.log",
    "early_stop": True,
}

# Train with labeled input data
automl.fit(X_train=X_train, y_train=y_train,
           **automl_settings)
# Predict
print(automl.predict_proba(X_train))
# Print the best model
print(automl.model.estimator)

# Output:
#LGBMClassifier(colsample_bytree=0.6888970622475563,
               #learning_rate=0.09951515716853933, max_bin=511,
               #min_child_samples=4, n_estimators=1, n_jobs=-1, num_leaves=13,
               #reg_alpha=0.007704104902643932, reg_lambda=9.757362285043104,
               #verbose=-1)
# Out:
# [flaml.automl.logger: 03-10 14:50:12] {1679} INFO - task = classification
# [flaml.automl.logger: 03-10 14:50:12] {1690} INFO - Evaluation method: holdout
# [flaml.automl.logger: 03-10 14:50:12] {1788} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 03-10 14:50:12] {1900} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl.logger: 03-10 14:50:12] {2218} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 03-10 14:50:12] {2344} INFO - Estimated sufficient time budget=1999s. Estimated necessary time budget=46s.
# [flaml.automl.logger: 03-10 14:50:12] {2391} INFO -  at 0.3s,	estimator lgbm's best error=0.5492,	best estimator lgbm's best error=0.5492
# [flaml.automl.logger: 03-10 14:50:12] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 03-10 14:50:12] {2391} INFO -  at 0.5s,	estimator lgbm's best error=0.5492,	best estimator lgbm's best error=0.5492
# [flaml.automl.logger: 03-10 14:50:12] {2218} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 03-10 14:50:12] {2391} INFO -  at 0.6s,	estimator lgbm's best error=0.5492,	best estimator lgbm's best error=0.5492
# [flaml.automl.logger: 03-10 14:50:12] {2218} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 03-10 14:50:12] {2391} INFO -  at 0.9s,	estimator xgboost's best error=0.5717,	best estimator lgbm's best error=0.5492
# [flaml.automl.logger: 03-10 14:50:12] {2218} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 03-10 14:50:13] {2391} INFO -  at 1.3s,	estimator lgbm's best error=0.4939,	best estimator lgbm's best error=0.4939
# [flaml.automl.logger: 03-10 14:50:13] {2218} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 03-10 14:50:13] {2391} INFO -  at 1.6s,	estimator xgboost's best error=0.5717,	best estimator lgbm's best error=0.4939
# [flaml.automl.logger: 03-10 14:50:13] {2218} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 03-10 14:50:14] {2391} INFO -  at 2.1s,	estimator lgbm's best error=0.4939,	best estimator lgbm's best error=0.4939
# [flaml.automl.logger: 03-10 14:50:14] {2218} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 03-10 14:50:14] {2391} INFO -  at 2.5s,	estimator lgbm's best error=0.4939,	best estimator lgbm's best error=0.4939
# [flaml.automl.logger: 03-10 14:50:14] {2218} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 03-10 14:50:14] {2391} INFO -  at 2.7s,	estimator lgbm's best error=0.4939,	best estimator lgbm's best error=0.4939
# [flaml.automl.logger: 03-10 14:50:14] {2218} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 03-10 14:50:15] {2391} INFO -  at 3.0s,	estimator xgboost's best error=0.5553,	best estimator lgbm's best error=0.4939
# [flaml.automl.logger: 03-10 14:50:15] {2218} INFO - iteration 10, current learner extra_tree
# [flaml.automl.logger: 03-10 14:50:15] {2391} INFO -  at 3.1s,	estimator extra_tree's best error=0.7049,	best estimator lgbm's best error=0.4939
# [flaml.automl.logger: 03-10 14:50:15] {2218} INFO - iteration 11, current learner extra_tree
# [flaml.automl.logger: 03-10 14:50:15] {2391} INFO -  at 3.1s,	estimator extra_tree's best error=0.6660,	best estimator lgbm's best error=0.4939
# [flaml.automl.logger: 03-10 14:50:15] {2218} INFO - iteration 12, current learner extra_tree
# [flaml.automl.logger: 03-10 14:50:15] {2391} INFO -  at 3.1s,	estimator extra_tree's best error=0.6660,	best estimator lgbm's best error=0.4939
# [flaml.automl.logger: 03-10 14:50:15] {2218} INFO - iteration 13, current learner rf
# [flaml.automl.logger: 03-10 14:50:15] {2391} INFO -  at 3.3s,	estimator rf's best error=0.6660,	best estimator lgbm's best error=0.4939
# [flaml.automl.logger: 03-10 14:50:15] {2218} INFO - iteration 14, current learner rf
# [flaml.automl.logger: 03-10 14:50:15] {2391} INFO -  at 3.4s,	estimator rf's best error=0.6045,	best estimator lgbm's best error=0.4939
# [flaml.automl.logger: 03-10 14:50:15] {2218} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 03-10 14:50:15] {2391} INFO -  at 3.7s,	estimator xgboost's best error=0.5553,	best estimator lgbm's best error=0.4939
# [flaml.automl.logger: 03-10 14:50:15] {2218} INFO - iteration 16, current learner rf
# [flaml.automl.logger: 03-10 14:50:15] {2391} INFO -  at 3.8s,	estimator rf's best error=0.6045,	best estimator lgbm's best error=0.4939
# [flaml.automl.logger: 03-10 14:50:15] {2218} INFO - iteration 17, current learner extra_tree
# [flaml.automl.logger: 03-10 14:50:15] {2391} INFO -  at 3.8s,	estimator extra_tree's best error=0.6209,	best estimator lgbm's best error=0.4939
# [flaml.automl.logger: 03-10 14:50:15] {2218} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 03-10 14:50:16] {2391} INFO -  at 4.5s,	estimator lgbm's best error=0.4672,	best estimator lgbm's best error=0.4672
# [flaml.automl.logger: 03-10 14:50:16] {2218} INFO - iteration 19, current learner extra_tree
# [flaml.automl.logger: 03-10 14:50:16] {2391} INFO -  at 4.6s,	estimator extra_tree's best error=0.6209,	best estimator lgbm's best error=0.4672
# [flaml.automl.logger: 03-10 14:50:16] {2218} INFO - iteration 20, current learner rf
# [flaml.automl.logger: 03-10 14:50:16] {2391} INFO -  at 4.9s,	estimator rf's best error=0.6004,	best estimator lgbm's best error=0.4672
# [flaml.automl.logger: 03-10 14:50:16] {2218} INFO - iteration 21, current learner extra_tree
# [flaml.automl.logger: 03-10 14:50:17] {2391} INFO -  at 4.9s,	estimator extra_tree's best error=0.5963,	best estimator lgbm's best error=0.4672
# [flaml.automl.logger: 03-10 14:50:17] {2218} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 03-10 14:50:17] {2391} INFO -  at 5.3s,	estimator lgbm's best error=0.4672,	best estimator lgbm's best error=0.4672
# [flaml.automl.logger: 03-10 14:50:17] {2218} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 03-10 14:50:22] {2391} INFO -  at 10.8s,	estimator lgbm's best error=0.4180,	best estimator lgbm's best error=0.4180
# [flaml.automl.logger: 03-10 14:50:22] {2218} INFO - iteration 24, current learner extra_tree
# [flaml.automl.logger: 03-10 14:50:22] {2391} INFO -  at 10.9s,	estimator extra_tree's best error=0.5963,	best estimator lgbm's best error=0.4180
# [flaml.automl.logger: 03-10 14:50:22] {2218} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 03-10 14:50:23] {2391} INFO -  at 11.0s,	estimator extra_tree's best error=0.5471,	best estimator lgbm's best error=0.4180
# [flaml.automl.logger: 03-10 14:50:23] {2218} INFO - iteration 26, current learner extra_tree
# [flaml.automl.logger: 03-10 14:50:23] {2391} INFO -  at 11.0s,	estimator extra_tree's best error=0.5471,	best estimator lgbm's best error=0.4180
# [flaml.automl.logger: 03-10 14:50:23] {2218} INFO - iteration 27, current learner extra_tree
# [flaml.automl.logger: 03-10 14:50:23] {2391} INFO -  at 11.1s,	estimator extra_tree's best error=0.5471,	best estimator lgbm's best error=0.4180
# [flaml.automl.logger: 03-10 14:50:23] {2218} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 03-10 14:50:23] {2391} INFO -  at 11.2s,	estimator extra_tree's best error=0.5123,	best estimator lgbm's best error=0.4180
# [flaml.automl.logger: 03-10 14:50:23] {2218} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 03-10 14:50:23] {2391} INFO -  at 11.3s,	estimator extra_tree's best error=0.5123,	best estimator lgbm's best error=0.4180
# [flaml.automl.logger: 03-10 14:50:23] {2218} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 03-10 14:50:32] {2391} INFO -  at 20.3s,	estimator lgbm's best error=0.3852,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:50:32] {2218} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 03-10 14:50:36] {2391} INFO -  at 24.0s,	estimator lgbm's best error=0.3852,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:50:36] {2218} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 03-10 14:50:40] {2391} INFO -  at 28.0s,	estimator lgbm's best error=0.3852,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:50:40] {2218} INFO - iteration 33, current learner extra_tree
# [flaml.automl.logger: 03-10 14:50:40] {2391} INFO -  at 28.1s,	estimator extra_tree's best error=0.4795,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:50:40] {2218} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 03-10 14:50:59] {2391} INFO -  at 47.4s,	estimator lgbm's best error=0.3852,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:50:59] {2218} INFO - iteration 35, current learner extra_tree
# [flaml.automl.logger: 03-10 14:50:59] {2391} INFO -  at 47.8s,	estimator extra_tree's best error=0.4795,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:50:59] {2218} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 03-10 14:51:00] {2391} INFO -  at 48.8s,	estimator extra_tree's best error=0.4795,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:51:00] {2218} INFO - iteration 37, current learner extra_tree
# [flaml.automl.logger: 03-10 14:51:01] {2391} INFO -  at 49.4s,	estimator extra_tree's best error=0.4734,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:51:01] {2218} INFO - iteration 38, current learner xgb_limitdepth
# [flaml.automl.logger: 03-10 14:51:06] {2391} INFO -  at 54.6s,	estimator xgb_limitdepth's best error=0.4734,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:51:06] {2218} INFO - iteration 39, current learner xgb_limitdepth
# [flaml.automl.logger: 03-10 14:51:11] {2391} INFO -  at 59.0s,	estimator xgb_limitdepth's best error=0.4734,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:51:11] {2218} INFO - iteration 40, current learner xgboost
# [flaml.automl.logger: 03-10 14:51:12] {2391} INFO -  at 60.1s,	estimator xgboost's best error=0.5553,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:51:12] {2218} INFO - iteration 41, current learner xgb_limitdepth
# [flaml.automl.logger: 03-10 14:51:17] {2391} INFO -  at 65.4s,	estimator xgb_limitdepth's best error=0.4734,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:51:17] {2218} INFO - iteration 42, current learner xgb_limitdepth
# [flaml.automl.logger: 03-10 14:51:20] {2391} INFO -  at 68.3s,	estimator xgb_limitdepth's best error=0.4734,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:51:20] {2218} INFO - iteration 43, current learner lgbm
# [flaml.automl.logger: 03-10 14:51:34] {2391} INFO -  at 82.1s,	estimator lgbm's best error=0.3852,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:51:34] {2218} INFO - iteration 44, current learner xgb_limitdepth
# [flaml.automl.logger: 03-10 14:51:42] {2391} INFO -  at 90.1s,	estimator xgb_limitdepth's best error=0.4734,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:51:42] {2218} INFO - iteration 45, current learner xgb_limitdepth
# [flaml.automl.logger: 03-10 14:51:44] {2391} INFO -  at 92.1s,	estimator xgb_limitdepth's best error=0.4734,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:51:44] {2218} INFO - iteration 46, current learner xgb_limitdepth
# [flaml.automl.logger: 03-10 14:51:52] {2391} INFO -  at 100.4s,	estimator xgb_limitdepth's best error=0.4344,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:51:52] {2218} INFO - iteration 47, current learner lrl1
# [flaml.automl.logger: 03-10 14:52:48] {2391} INFO -  at 156.1s,	estimator lrl1's best error=0.4262,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:52:48] {2218} INFO - iteration 48, current learner rf
# c:\Users\Sissi\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [flaml.automl.logger: 03-10 14:52:49] {2391} INFO -  at 157.3s,	estimator rf's best error=0.6004,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:52:49] {2218} INFO - iteration 49, current learner xgb_limitdepth
# [flaml.automl.logger: 03-10 14:52:58] {2391} INFO -  at 166.1s,	estimator xgb_limitdepth's best error=0.4344,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:52:58] {2218} INFO - iteration 50, current learner lgbm
# [flaml.automl.logger: 03-10 14:53:03] {2391} INFO -  at 171.7s,	estimator lgbm's best error=0.3852,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:53:03] {2218} INFO - iteration 51, current learner xgboost
# [flaml.automl.logger: 03-10 14:53:04] {2391} INFO -  at 172.4s,	estimator xgboost's best error=0.5471,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:53:04] {2218} INFO - iteration 52, current learner lrl1
# [flaml.automl.logger: 03-10 14:54:30] {2391} INFO -  at 258.7s,	estimator lrl1's best error=0.4180,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:54:30] {2218} INFO - iteration 53, current learner lgbm
# c:\Users\Sissi\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [flaml.automl.logger: 03-10 14:55:17] {2391} INFO -  at 305.9s,	estimator lgbm's best error=0.3852,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:55:17] {2218} INFO - iteration 54, current learner xgboost
# [flaml.automl.logger: 03-10 14:55:19] {2391} INFO -  at 307.2s,	estimator xgboost's best error=0.5143,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:55:19] {2218} INFO - iteration 55, current learner xgboost
# [flaml.automl.logger: 03-10 14:55:21] {2391} INFO -  at 309.1s,	estimator xgboost's best error=0.5143,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:55:21] {2218} INFO - iteration 56, current learner lgbm
# [flaml.automl.logger: 03-10 14:55:26] {2391} INFO -  at 314.3s,	estimator lgbm's best error=0.3852,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:55:26] {2218} INFO - iteration 57, current learner extra_tree
# [flaml.automl.logger: 03-10 14:55:26] {2391} INFO -  at 314.9s,	estimator extra_tree's best error=0.4734,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:55:26] {2218} INFO - iteration 58, current learner xgboost
# [flaml.automl.logger: 03-10 14:55:27] {2391} INFO -  at 315.9s,	estimator xgboost's best error=0.5143,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:55:27] {2218} INFO - iteration 59, current learner xgboost
# [flaml.automl.logger: 03-10 14:55:30] {2391} INFO -  at 318.6s,	estimator xgboost's best error=0.4836,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:55:30] {2218} INFO - iteration 60, current learner xgboost
# [flaml.automl.logger: 03-10 14:55:32] {2391} INFO -  at 320.0s,	estimator xgboost's best error=0.4836,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:55:32] {2218} INFO - iteration 61, current learner lgbm
# [flaml.automl.logger: 03-10 14:55:38] {2391} INFO -  at 326.8s,	estimator lgbm's best error=0.3852,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:55:38] {2218} INFO - iteration 62, current learner xgboost
# [flaml.automl.logger: 03-10 14:55:40] {2391} INFO -  at 328.1s,	estimator xgboost's best error=0.4836,	best estimator lgbm's best error=0.3852
# [flaml.automl.logger: 03-10 14:55:40] {2218} INFO - iteration 63, current learner lgbm
# [flaml.automl.logger: 03-10 14:56:22] {2391} INFO -  at 370.3s,	estimator lgbm's best error=0.3811,	best estimator lgbm's best error=0.3811
# [flaml.automl.logger: 03-10 14:56:22] {2218} INFO - iteration 64, current learner extra_tree
# [flaml.automl.logger: 03-10 14:56:22] {2391} INFO -  at 370.7s,	estimator extra_tree's best error=0.4734,	best estimator lgbm's best error=0.3811
# [flaml.automl.logger: 03-10 14:56:22] {2218} INFO - iteration 65, current learner extra_tree
# [flaml.automl.logger: 03-10 14:56:23] {2391} INFO -  at 371.5s,	estimator extra_tree's best error=0.4590,	best estimator lgbm's best error=0.3811
# [flaml.automl.logger: 03-10 14:56:23] {2218} INFO - iteration 66, current learner rf
# [flaml.automl.logger: 03-10 14:56:24] {2391} INFO -  at 372.6s,	estimator rf's best error=0.6004,	best estimator lgbm's best error=0.3811
# [flaml.automl.logger: 03-10 14:56:24] {2218} INFO - iteration 67, current learner extra_tree
# [flaml.automl.logger: 03-10 14:56:25] {2391} INFO -  at 373.6s,	estimator extra_tree's best error=0.4590,	best estimator lgbm's best error=0.3811
# [flaml.automl.logger: 03-10 14:56:25] {2218} INFO - iteration 68, current learner extra_tree
# [flaml.automl.logger: 03-10 14:56:26] {2391} INFO -  at 374.4s,	estimator extra_tree's best error=0.4590,	best estimator lgbm's best error=0.3811
# [flaml.automl.logger: 03-10 14:56:26] {2218} INFO - iteration 69, current learner xgboost
# [flaml.automl.logger: 03-10 14:56:31] {2391} INFO -  at 379.7s,	estimator xgboost's best error=0.4467,	best estimator lgbm's best error=0.3811
# [flaml.automl.logger: 03-10 14:56:31] {2218} INFO - iteration 70, current learner lgbm
# [flaml.automl.logger: 03-10 14:57:50] {2391} INFO -  at 458.3s,	estimator lgbm's best error=0.3689,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:57:50] {2218} INFO - iteration 71, current learner xgboost
# [flaml.automl.logger: 03-10 14:57:54] {2391} INFO -  at 462.7s,	estimator xgboost's best error=0.4467,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:57:54] {2218} INFO - iteration 72, current learner extra_tree
# [flaml.automl.logger: 03-10 14:57:55] {2391} INFO -  at 463.6s,	estimator extra_tree's best error=0.4590,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:57:55] {2218} INFO - iteration 73, current learner xgboost
# [flaml.automl.logger: 03-10 14:58:02] {2391} INFO -  at 470.5s,	estimator xgboost's best error=0.4467,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:58:02] {2218} INFO - iteration 74, current learner xgb_limitdepth
# [flaml.automl.logger: 03-10 14:58:09] {2391} INFO -  at 477.2s,	estimator xgb_limitdepth's best error=0.4262,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:58:09] {2218} INFO - iteration 75, current learner extra_tree
# [flaml.automl.logger: 03-10 14:58:10] {2391} INFO -  at 478.1s,	estimator extra_tree's best error=0.4590,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:58:10] {2218} INFO - iteration 76, current learner xgb_limitdepth
# [flaml.automl.logger: 03-10 14:58:18] {2391} INFO -  at 486.7s,	estimator xgb_limitdepth's best error=0.4262,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:58:18] {2218} INFO - iteration 77, current learner lgbm
# [flaml.automl.logger: 03-10 14:59:01] {2391} INFO -  at 529.7s,	estimator lgbm's best error=0.3689,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:59:01] {2218} INFO - iteration 78, current learner xgboost
# [flaml.automl.logger: 03-10 14:59:03] {2391} INFO -  at 531.9s,	estimator xgboost's best error=0.4467,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:59:03] {2218} INFO - iteration 79, current learner extra_tree
# [flaml.automl.logger: 03-10 14:59:05] {2391} INFO -  at 533.3s,	estimator extra_tree's best error=0.4590,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:59:05] {2218} INFO - iteration 80, current learner xgboost
# [flaml.automl.logger: 03-10 14:59:16] {2391} INFO -  at 544.0s,	estimator xgboost's best error=0.4467,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:59:16] {2218} INFO - iteration 81, current learner xgboost
# [flaml.automl.logger: 03-10 14:59:17] {2391} INFO -  at 545.5s,	estimator xgboost's best error=0.4467,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:59:17] {2218} INFO - iteration 82, current learner xgb_limitdepth
# [flaml.automl.logger: 03-10 14:59:22] {2391} INFO -  at 550.0s,	estimator xgb_limitdepth's best error=0.4262,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:59:22] {2218} INFO - iteration 83, current learner xgboost
# [flaml.automl.logger: 03-10 14:59:36] {2391} INFO -  at 564.4s,	estimator xgboost's best error=0.4467,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:59:36] {2218} INFO - iteration 84, current learner extra_tree
# [flaml.automl.logger: 03-10 14:59:37] {2391} INFO -  at 565.0s,	estimator extra_tree's best error=0.4590,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:59:37] {2218} INFO - iteration 85, current learner extra_tree
# [flaml.automl.logger: 03-10 14:59:37] {2391} INFO -  at 565.9s,	estimator extra_tree's best error=0.4590,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:59:37] {2218} INFO - iteration 86, current learner xgb_limitdepth
# [flaml.automl.logger: 03-10 14:59:42] {2391} INFO -  at 570.2s,	estimator xgb_limitdepth's best error=0.4262,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:59:42] {2218} INFO - iteration 87, current learner extra_tree
# [flaml.automl.logger: 03-10 14:59:43] {2391} INFO -  at 571.0s,	estimator extra_tree's best error=0.4590,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:59:43] {2218} INFO - iteration 88, current learner extra_tree
# [flaml.automl.logger: 03-10 14:59:44] {2391} INFO -  at 572.2s,	estimator extra_tree's best error=0.4590,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:59:44] {2218} INFO - iteration 89, current learner xgboost
# [flaml.automl.logger: 03-10 14:59:45] {2391} INFO -  at 573.3s,	estimator xgboost's best error=0.4467,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 14:59:45] {2218} INFO - iteration 90, current learner xgboost
# [flaml.automl.logger: 03-10 15:00:06] {2391} INFO -  at 594.3s,	estimator xgboost's best error=0.4467,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 15:00:06] {2218} INFO - iteration 91, current learner extra_tree
# [flaml.automl.logger: 03-10 15:00:06] {2391} INFO -  at 594.9s,	estimator extra_tree's best error=0.4508,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 15:00:06] {2218} INFO - iteration 92, current learner extra_tree
# [flaml.automl.logger: 03-10 15:00:07] {2391} INFO -  at 595.5s,	estimator extra_tree's best error=0.4508,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 15:00:07] {2218} INFO - iteration 93, current learner extra_tree
# [flaml.automl.logger: 03-10 15:00:08] {2391} INFO -  at 596.1s,	estimator extra_tree's best error=0.4508,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 15:00:08] {2218} INFO - iteration 94, current learner extra_tree
# [flaml.automl.logger: 03-10 15:00:08] {2391} INFO -  at 596.9s,	estimator extra_tree's best error=0.4508,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 15:00:08] {2218} INFO - iteration 95, current learner extra_tree
# [flaml.automl.logger: 03-10 15:00:09] {2391} INFO -  at 597.4s,	estimator extra_tree's best error=0.4508,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 15:00:09] {2218} INFO - iteration 96, current learner rf
# [flaml.automl.logger: 03-10 15:00:09] {2391} INFO -  at 597.9s,	estimator rf's best error=0.5799,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 15:00:09] {2218} INFO - iteration 97, current learner extra_tree
# [flaml.automl.logger: 03-10 15:00:10] {2391} INFO -  at 598.4s,	estimator extra_tree's best error=0.4508,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 15:00:10] {2218} INFO - iteration 98, current learner rf
# [flaml.automl.logger: 03-10 15:00:11] {2391} INFO -  at 599.8s,	estimator rf's best error=0.5307,	best estimator lgbm's best error=0.3689
# [flaml.automl.logger: 03-10 15:01:23] {2627} INFO - retrain lgbm for 71.3s
# [flaml.automl.logger: 03-10 15:01:23] {2630} INFO - retrained model: LGBMClassifier(colsample_bytree=0.6026084094906663,
#                learning_rate=0.10856696902873961, max_bin=1023,
#                min_child_samples=3, n_estimators=1, n_jobs=-1, num_leaves=18,
#                reg_alpha=0.004577823970660193, reg_lambda=0.04610442348224643,
#                verbose=-1)
# [flaml.automl.logger: 03-10 15:01:23] {1930} INFO - fit succeeded
# [flaml.automl.logger: 03-10 15:01:23] {1931} INFO - Time taken to find the best model: 458.3349418640137
# [[1.84773782e-05 4.03618092e-05 2.97197342e-04 ... 1.27672716e-04
#   4.44676990e-04 9.98923562e-01]
#  [2.14853408e-04 1.22448094e-05 9.25649787e-07 ... 3.64123642e-04
#   9.63178873e-05 5.25078728e-06]
#  [9.99282692e-01 2.26274113e-04 2.31149561e-05 ... 1.13020801e-05
#   7.86237455e-05 1.96522615e-04]
#  ...
#  [4.78151498e-05 6.23211127e-04 6.17975560e-05 ... 3.19158689e-05
#   9.98403952e-01 7.19980667e-04]
#  [3.24560611e-04 1.16004150e-04 6.53453747e-06 ... 9.98802462e-01
#   2.76341833e-04 1.90917423e-05]
#  [9.98427727e-01 2.65144349e-04 4.68997441e-06 ... 9.71045022e-05
#   1.03822513e-03 6.91969474e-05]]
# LGBMClassifier(colsample_bytree=0.6026084094906663,
#                learning_rate=0.10856696902873961, max_bin=1023,
#                min_child_samples=3, n_estimators=1, n_jobs=-1, num_leaves=18,
#                reg_alpha=0.004577823970660193, reg_lambda=0.04610442348224643,
#                verbose=-1)

# %%
x_pred = automl.predict(X_val)
print('accuracy', '=', 1 - sklearn_metric_loss_score('accuracy', x_pred, y_val))
# 0.615
# Out:
# accuracy = 0.5983333333333334

# %%
X_test = scalerx.transform(X_test)
X_test_lda = lda.transform(X_test)
y_pred = automl.predict(X_test) # compute predictions on the test inputs
y_pred
# Out:
# array([4, 6, 5, ..., 1, 6, 6])

# %%
y_pred_dec = label_encoder.inverse_transform(y_pred)
y_pred_dec
# Out:
# array(['Instrumental', 'Pop', 'International', ..., 'Experimental', 'Pop',
#        'Pop'], dtype=object)

# %% [markdown]
# ## Export in csv format

# %%
# Export the predictions on the test data in csv format
prediction = pd.DataFrame(y_pred, columns=['Genre'])
prediction.index.name='Id'
prediction.to_csv('myprediction.csv') # export to csv file

# The csv file should be of the form
#Id, Genre
#0, Folk
#1, Hip-Hop
#2, International
#...
#1998, Experimental
#1999, Pop
