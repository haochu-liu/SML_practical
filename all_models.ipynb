# %% [markdown]
# # Combine all models
# MSc in Statistical Science\
# University of Oxford\
# Group-assessed practical\
# HT 2024

# %%
# Import libraries
import pandas as pd
import numpy as np
from search_param.grid_search import read_data, decode_dict
from fit_models import fit_model
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score
import shutil
import json
import time

# %% [markdown]
# ## Data processing

# %%
X_train, X_val, y_train, y_val = read_data()

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit label encoder and return encoded labels
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)

# Convert labels to one-hot encoding
y_train_onehot = to_categorical(y_train_encoded)
y_val_onehot = to_categorical(y_val_encoded)

# %%
# Standard scaling
scaler = StandardScaler()
scaler.fit(X_train)
X_train_sc = scaler.transform(X_train)
X_val_sc = scaler.transform(X_val)

# %%
# LDA
lda = LinearDiscriminantAnalysis(n_components=None)
X_train_lda = lda.fit_transform(X_train, y_train)
X_val_lda = lda.transform(X_val)

# %%
# PCA
p_PCA = 25 # from notebook pictures
pca = PCA(n_components=p_PCA, random_state=42)  # Select top 25 components
X_train_pca = pca.fit_transform(X_train_sc)
X_val_pca = pca.transform(X_val_sc)

# %% [markdown]
# ## Create dataframe

# %%
column_names = ['Model', 'Pre-processing', 'Training time (sec)', 'Training acc', 'Testing acc']

performance = pd.DataFrame({col: [np.nan] * 17 for col in column_names})
performance
# Out:
#     Model  Pre-processing  Training time (sec)  Training acc  Testing acc
# 0     NaN             NaN                  NaN           NaN          NaN
# 1     NaN             NaN                  NaN           NaN          NaN
# 2     NaN             NaN                  NaN           NaN          NaN
# 3     NaN             NaN                  NaN           NaN          NaN
# 4     NaN             NaN                  NaN           NaN          NaN
# 5     NaN             NaN                  NaN           NaN          NaN
# 6     NaN             NaN                  NaN           NaN          NaN
# 7     NaN             NaN                  NaN           NaN          NaN
# 8     NaN             NaN                  NaN           NaN          NaN
# 9     NaN             NaN                  NaN           NaN          NaN
# 10    NaN             NaN                  NaN           NaN          NaN
# 11    NaN             NaN                  NaN           NaN          NaN
# 12    NaN             NaN                  NaN           NaN          NaN
# 13    NaN             NaN                  NaN           NaN          NaN
# 14    NaN             NaN                  NaN           NaN          NaN
# 15    NaN             NaN                  NaN           NaN          NaN
# 16    NaN             NaN                  NaN           NaN          NaN

# %%
y_train_pred = []
y_val_pred = []

# %% [markdown]
# ## Neural Network

# %%
performance.iloc[0, 0] = 'Neural Network'
performance.iloc[0, 1] = 'Scaling'

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model

# %%
# Load JSON file into Python dictionary
with open('search_nn/sc_param.json', 'r') as f:
    config = json.load(f)

# %%
nn_model = Sequential.from_config(config)
nn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 160)            │        83,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 416)            │        66,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 416)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 416)            │       173,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 416)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8)              │         3,336 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 326,824 (1.25 MB)
#  Trainable params: 326,824 (1.25 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
nn_model.compile(optimizer="adam",
                 loss='categorical_crossentropy',  # Suitable for multi-class classification
                 metrics=['accuracy'])

# %%
start_time = time.time()

nn_model.fit(X_train_sc, y_train_onehot,
             validation_data=(X_val_sc, y_val_onehot),
             epochs=20)

end_time = time.time()
performance.iloc[0, 2] = end_time - start_time
# Out:
# Epoch 1/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.2315 - loss: 2.0943 - val_accuracy: 0.4825 - val_loss: 1.4987
# Epoch 2/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4731 - loss: 1.4480 - val_accuracy: 0.5408 - val_loss: 1.3425
# Epoch 3/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5724 - loss: 1.2141 - val_accuracy: 0.5375 - val_loss: 1.3093
# Epoch 4/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5945 - loss: 1.1606 - val_accuracy: 0.5633 - val_loss: 1.2681
# Epoch 5/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6448 - loss: 1.0297 - val_accuracy: 0.5650 - val_loss: 1.2681
# Epoch 6/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6434 - loss: 1.0010 - val_accuracy: 0.5708 - val_loss: 1.2447
# Epoch 7/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6543 - loss: 0.9857 - val_accuracy: 0.5833 - val_loss: 1.2641
# Epoch 8/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6831 - loss: 0.9228 - val_accuracy: 0.5742 - val_loss: 1.2281
# Epoch 9/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7001 - loss: 0.8814 - val_accuracy: 0.5750 - val_loss: 1.2747
# Epoch 10/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7327 - loss: 0.7981 - val_accuracy: 0.5750 - val_loss: 1.2648
# Epoch 11/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7529 - loss: 0.7427 - val_accuracy: 0.5783 - val_loss: 1.2815
# Epoch 12/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7462 - loss: 0.7498 - val_accuracy: 0.5792 - val_loss: 1.3383
# Epoch 13/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7663 - loss: 0.7008 - val_accuracy: 0.5792 - val_loss: 1.3693
# Epoch 14/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7792 - loss: 0.6453 - val_accuracy: 0.5892 - val_loss: 1.3465
# Epoch 15/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7766 - loss: 0.6615 - val_accuracy: 0.5933 - val_loss: 1.4772
# Epoch 16/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7853 - loss: 0.6221 - val_accuracy: 0.5833 - val_loss: 1.4449
# Epoch 17/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7975 - loss: 0.5829 - val_accuracy: 0.5675 - val_loss: 1.5298
# Epoch 18/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8141 - loss: 0.5264 - val_accuracy: 0.5642 - val_loss: 1.4731
# Epoch 19/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8240 - loss: 0.5148 - val_accuracy: 0.5717 - val_loss: 1.5665
# Epoch 20/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8410 - loss: 0.4644 - val_accuracy: 0.5808 - val_loss: 1.6620

# %%
y_train_pred.append(nn_model.predict(X_train_sc).argmax(axis=-1))
train_loss, performance.iloc[0, 3] = nn_model.evaluate(X_train_sc, y_train_onehot, verbose=0)
# Out:
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
y_val_pred.append(nn_model.predict(X_val_sc).argmax(axis=-1))
test_loss, performance.iloc[0, 4] = nn_model.evaluate(X_val_sc, y_val_onehot)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6064 - loss: 1.5387

# %%
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401        0.9025
# 1              NaN            NaN                  NaN           NaN
# 2              NaN            NaN                  NaN           NaN
# 3              NaN            NaN                  NaN           NaN
# 4              NaN            NaN                  NaN           NaN
# 5              NaN            NaN                  NaN           NaN
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %% [markdown]
# ## XGB

# %%
i = 1
performance.iloc[i, 0] = 'XGBooster'
performance.iloc[i, 1] = 'Scaling'

# %%
from xgboost import XGBClassifier


model = XGBClassifier(
    objective='multi:softmax',   # for multiclass classification
    num_class=8,                 # specify the number of classes
)
performance.iloc[i, 2:5], y_train_pred_m, y_val_pred_m  = fit_model(model, 'search_param/xgb_param.json', 'scaler',
    X_train_sc, y_train_encoded, X_val_sc, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401        0.9025
# 1        XGBooster        Scaling           115.175411        1.0000
# 2              NaN            NaN                  NaN           NaN
# 3              NaN            NaN                  NaN           NaN
# 4              NaN            NaN                  NaN           NaN
# 5              NaN            NaN                  NaN           NaN
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
y_train_pred.append(y_train_pred_m)
y_val_pred.append(y_val_pred_m)

# %% [markdown]
# ## Random Forest

# %%
performance.iloc[i, 0] = 'Random Forest'
performance.iloc[i, 1] = 'Scaling'

# %%
from sklearn.ensemble import RandomForestClassifier


model = RandomForestClassifier()
performance.iloc[i, 2:5], y_train_pred_m, y_val_pred_m  = fit_model(model, 'search_param/rf_param.json', 'scaler',
    X_train_sc, y_train_encoded, X_val_sc, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401        0.9025
# 1        XGBooster        Scaling           115.175411        1.0000
# 2    Random Forest        Scaling            48.204262        1.0000
# 3              NaN            NaN                  NaN           NaN
# 4              NaN            NaN                  NaN           NaN
# 5              NaN            NaN                  NaN           NaN
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2      0.561667
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
y_train_pred.append(y_train_pred_m)
y_val_pred.append(y_val_pred_m)

# %% [markdown]
# ## AdaBooster

# %%
performance.iloc[i, 0] = 'AdaBooster'
performance.iloc[i, 1] = 'Scaling'

# %%
from sklearn.ensemble import AdaBoostClassifier


model = AdaBoostClassifier(random_state=42)
performance.iloc[i, 2:5], y_train_pred_m, y_val_pred_m  = fit_model(model, 'search_param/abc_param.json', 'scaler',
    X_train_sc, y_train_encoded, X_val_sc, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401      0.902500
# 1        XGBooster        Scaling           115.175411      1.000000
# 2    Random Forest        Scaling            48.204262      1.000000
# 3       AdaBooster        Scaling            52.048564      0.482083
# 4              NaN            NaN                  NaN           NaN
# 5              NaN            NaN                  NaN           NaN
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2      0.561667
# 3      0.449167
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
y_train_pred.append(y_train_pred_m)
y_val_pred.append(y_val_pred_m)

# %% [markdown]
# ## Logistic

# %%
performance.iloc[i, 0] = 'Logistic'
performance.iloc[i, 1] = 'Scaling'

# %%
from sklearn.linear_model import LogisticRegression


model = LogisticRegression()
performance.iloc[i, 2:5], y_train_pred_1, y_val_pred_1  = fit_model(model, 'search_param/logistic_param.json', 'scaler',
    X_train_sc, y_train_encoded, X_val_sc, y_val_encoded)

i += 1
performance
# Out:
# c:\Users\Liu_h\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401      0.902500
# 1        XGBooster        Scaling           115.175411      1.000000
# 2    Random Forest        Scaling            48.204262      1.000000
# 3       AdaBooster        Scaling            52.048564      0.482083
# 4         Logistic        Scaling             0.567590      0.692708
# 5              NaN            NaN                  NaN           NaN
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2      0.561667
# 3      0.449167
# 4      0.567500
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'Logistic'
performance.iloc[i, 1] = 'PCA'

# %%
model = LogisticRegression()
performance.iloc[i, 2:5], y_train_pred_2, y_val_pred_2  = fit_model(model, 'search_param/logistic_param.json', 'pca',
    X_train_pca, y_train_encoded, X_val_pca, y_val_encoded)

i += 1
performance
# Out:
# c:\Users\Liu_h\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401      0.902500
# 1        XGBooster        Scaling           115.175411      1.000000
# 2    Random Forest        Scaling            48.204262      1.000000
# 3       AdaBooster        Scaling            52.048564      0.482083
# 4         Logistic        Scaling             0.567590      0.692708
# 5         Logistic            PCA             0.628999      0.692708
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2      0.561667
# 3      0.449167
# 4      0.567500
# 5      0.567500
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'Logistic'
performance.iloc[i, 1] = 'LDA'

# %%
model = LogisticRegression()
performance.iloc[i, 2:5], y_train_pred_3, y_val_pred_3  = fit_model(model, 'search_param/logistic_param.json', 'lda',
    X_train_lda, y_train_encoded, X_val_lda, y_val_encoded)

i += 1
performance
# Out:
# c:\Users\Liu_h\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# c:\Users\Liu_h\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401      0.902500
# 1        XGBooster        Scaling           115.175411      1.000000
# 2    Random Forest        Scaling            48.204262      1.000000
# 3       AdaBooster        Scaling            52.048564      0.482083
# 4         Logistic        Scaling             0.567590      0.692708
# 5         Logistic            PCA             0.628999      0.692708
# 6         Logistic            LDA             0.607732      0.774167
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2      0.561667
# 3      0.449167
# 4      0.567500
# 5      0.567500
# 6      0.523333
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
y_train_pred.append(y_train_pred_1)
y_val_pred.append(y_val_pred_1)

# %% [markdown]
# ## SVM

# %%
performance.iloc[i, 0] = 'SVM'
performance.iloc[i, 1] = 'Scaling'

# %%
from sklearn.svm import SVC


model = SVC()
performance.iloc[i, 2:5], y_train_pred_1, y_val_pred_1  = fit_model(model, 'search_param/svm_param.json', 'scaler',
    X_train_sc, y_train_encoded, X_val_sc, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401      0.902500
# 1        XGBooster        Scaling           115.175411      1.000000
# 2    Random Forest        Scaling            48.204262      1.000000
# 3       AdaBooster        Scaling            52.048564      0.482083
# 4         Logistic        Scaling             0.567590      0.692708
# 5         Logistic            PCA             0.628999      0.692708
# 6         Logistic            LDA             0.607732      0.774167
# 7              SVM        Scaling             9.294330      0.999167
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2      0.561667
# 3      0.449167
# 4      0.567500
# 5      0.567500
# 6      0.523333
# 7      0.615833
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'SVM'
performance.iloc[i, 1] = 'PCA'

# %%
model = SVC()
performance.iloc[i, 2:5], y_train_pred_2, y_val_pred_2  = fit_model(model, 'search_param/svm_param.json', 'pca',
    X_train_pca, y_train_encoded, X_val_pca, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401      0.902500
# 1        XGBooster        Scaling           115.175411      1.000000
# 2    Random Forest        Scaling            48.204262      1.000000
# 3       AdaBooster        Scaling            52.048564      0.482083
# 4         Logistic        Scaling             0.567590      0.692708
# 5         Logistic            PCA             0.628999      0.692708
# 6         Logistic            LDA             0.607732      0.774167
# 7              SVM        Scaling             9.294330      0.999167
# 8              SVM            PCA             8.810364      0.822292
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2      0.561667
# 3      0.449167
# 4      0.567500
# 5      0.567500
# 6      0.523333
# 7      0.615833
# 8      0.597500
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'SVM'
performance.iloc[i, 1] = 'LDA'

# %%
model = SVC()
performance.iloc[i, 2:5], y_train_pred_3, y_val_pred_3  = fit_model(model, 'search_param/svm_param.json', 'lda',
    X_train_lda, y_train_encoded, X_val_lda, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401      0.902500
# 1        XGBooster        Scaling           115.175411      1.000000
# 2    Random Forest        Scaling            48.204262      1.000000
# 3       AdaBooster        Scaling            52.048564      0.482083
# 4         Logistic        Scaling             0.567590      0.692708
# 5         Logistic            PCA             0.628999      0.692708
# 6         Logistic            LDA             0.607732      0.774167
# 7              SVM        Scaling             9.294330      0.999167
# 8              SVM            PCA             8.810364      0.822292
# 9              SVM            LDA             8.715013      0.536458
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2      0.561667
# 3      0.449167
# 4      0.567500
# 5      0.567500
# 6      0.523333
# 7      0.615833
# 8      0.597500
# 9      0.478333
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
y_train_pred.append(y_train_pred_1)
y_val_pred.append(y_val_pred_1)

# %% [markdown]
# ## KNN

# %%
performance.iloc[i, 0] = 'KNN'
performance.iloc[i, 1] = 'Scaling'

# %%
from sklearn.neighbors import KNeighborsClassifier


model = KNeighborsClassifier()
performance.iloc[i, 2:5], y_train_pred_1, y_val_pred_1  = fit_model(model, 'search_param/knn_param.json', 'scaler',
    X_train_sc, y_train_encoded, X_val_sc, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401      0.902500
# 1        XGBooster        Scaling           115.175411      1.000000
# 2    Random Forest        Scaling            48.204262      1.000000
# 3       AdaBooster        Scaling            52.048564      0.482083
# 4         Logistic        Scaling             0.567590      0.692708
# 5         Logistic            PCA             0.628999      0.692708
# 6         Logistic            LDA             0.607732      0.774167
# 7              SVM        Scaling             9.294330      0.999167
# 8              SVM            PCA             8.810364      0.822292
# 9              SVM            LDA             8.715013      0.536458
# 10             KNN        Scaling             0.019781      0.567083
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2      0.561667
# 3      0.449167
# 4      0.567500
# 5      0.567500
# 6      0.523333
# 7      0.615833
# 8      0.597500
# 9      0.478333
# 10     0.505000
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'KNN'
performance.iloc[i, 1] = 'PCA'

# %%
model = KNeighborsClassifier()
performance.iloc[i, 2:5], y_train_pred_2, y_val_pred_2  = fit_model(model, 'search_param/knn_param.json', 'pca',
    X_train_pca, y_train_encoded, X_val_pca, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401      0.902500
# 1        XGBooster        Scaling           115.175411      1.000000
# 2    Random Forest        Scaling            48.204262      1.000000
# 3       AdaBooster        Scaling            52.048564      0.482083
# 4         Logistic        Scaling             0.567590      0.692708
# 5         Logistic            PCA             0.628999      0.692708
# 6         Logistic            LDA             0.607732      0.774167
# 7              SVM        Scaling             9.294330      0.999167
# 8              SVM            PCA             8.810364      0.822292
# 9              SVM            LDA             8.715013      0.536458
# 10             KNN        Scaling             0.019781      0.567083
# 11             KNN            PCA             0.020159      0.569792
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2      0.561667
# 3      0.449167
# 4      0.567500
# 5      0.567500
# 6      0.523333
# 7      0.615833
# 8      0.597500
# 9      0.478333
# 10     0.505000
# 11     0.500833
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'KNN'
performance.iloc[i, 1] = 'LDA'

# %%
model = KNeighborsClassifier()
performance.iloc[i, 2:5], y_train_pred_3, y_val_pred_3  = fit_model(model, 'search_param/knn_param.json', 'lda',
    X_train_lda, y_train_encoded, X_val_lda, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401      0.902500
# 1        XGBooster        Scaling           115.175411      1.000000
# 2    Random Forest        Scaling            48.204262      1.000000
# 3       AdaBooster        Scaling            52.048564      0.482083
# 4         Logistic        Scaling             0.567590      0.692708
# 5         Logistic            PCA             0.628999      0.692708
# 6         Logistic            LDA             0.607732      0.774167
# 7              SVM        Scaling             9.294330      0.999167
# 8              SVM            PCA             8.810364      0.822292
# 9              SVM            LDA             8.715013      0.536458
# 10             KNN        Scaling             0.019781      0.567083
# 11             KNN            PCA             0.020159      0.569792
# 12             KNN            LDA             0.018030      0.538750
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2      0.561667
# 3      0.449167
# 4      0.567500
# 5      0.567500
# 6      0.523333
# 7      0.615833
# 8      0.597500
# 9      0.478333
# 10     0.505000
# 11     0.500833
# 12     0.497500
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
y_train_pred.append(y_train_pred_1)
y_val_pred.append(y_val_pred_1)

# %% [markdown]
# ## Naive Bayes

# %%
performance.iloc[i, 0] = 'Naive Bayes'
performance.iloc[i, 1] = 'Scaling'

# %%
from sklearn.neighbors import KNeighborsClassifier


model = KNeighborsClassifier()

start_time = time.time()
model.fit(X_train_sc, y_train_encoded)

end_time = time.time()
performance.iloc[i, 2] = end_time - start_time

y_train_pred_1 = model.predict(X_train_sc)
y_val_pred_1 = model.predict(X_val_sc)

performance.iloc[i, 3] = accuracy_score(y_train_encoded, y_train_pred_1)
performance.iloc[i, 4] = accuracy_score(y_val_encoded, y_val_pred_1)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401      0.902500
# 1        XGBooster        Scaling           115.175411      1.000000
# 2    Random Forest        Scaling            48.204262      1.000000
# 3       AdaBooster        Scaling            52.048564      0.482083
# 4         Logistic        Scaling             0.567590      0.692708
# 5         Logistic            PCA             0.628999      0.692708
# 6         Logistic            LDA             0.607732      0.774167
# 7              SVM        Scaling             9.294330      0.999167
# 8              SVM            PCA             8.810364      0.822292
# 9              SVM            LDA             8.715013      0.536458
# 10             KNN        Scaling             0.019781      0.567083
# 11             KNN            PCA             0.020159      0.569792
# 12             KNN            LDA             0.018030      0.538750
# 13     Naive Bayes        Scaling             0.019555      0.638542
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2      0.561667
# 3      0.449167
# 4      0.567500
# 5      0.567500
# 6      0.523333
# 7      0.615833
# 8      0.597500
# 9      0.478333
# 10     0.505000
# 11     0.500833
# 12     0.497500
# 13     0.472500
# 14          NaN
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'Naive Bayes'
performance.iloc[i, 1] = 'PCA'

# %%
model = KNeighborsClassifier()

start_time = time.time()
model.fit(X_train_pca, y_train_encoded)

end_time = time.time()
performance.iloc[i, 2] = end_time - start_time

y_train_pred_2 = model.predict(X_train_pca)
y_val_pred_2 = model.predict(X_val_pca)

performance.iloc[i, 3] = accuracy_score(y_train_encoded, y_train_pred_2)
performance.iloc[i, 4] = accuracy_score(y_val_encoded, y_val_pred_2)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401      0.902500
# 1        XGBooster        Scaling           115.175411      1.000000
# 2    Random Forest        Scaling            48.204262      1.000000
# 3       AdaBooster        Scaling            52.048564      0.482083
# 4         Logistic        Scaling             0.567590      0.692708
# 5         Logistic            PCA             0.628999      0.692708
# 6         Logistic            LDA             0.607732      0.774167
# 7              SVM        Scaling             9.294330      0.999167
# 8              SVM            PCA             8.810364      0.822292
# 9              SVM            LDA             8.715013      0.536458
# 10             KNN        Scaling             0.019781      0.567083
# 11             KNN            PCA             0.020159      0.569792
# 12             KNN            LDA             0.018030      0.538750
# 13     Naive Bayes        Scaling             0.019555      0.638542
# 14     Naive Bayes            PCA             0.003792      0.635000
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2      0.561667
# 3      0.449167
# 4      0.567500
# 5      0.567500
# 6      0.523333
# 7      0.615833
# 8      0.597500
# 9      0.478333
# 10     0.505000
# 11     0.500833
# 12     0.497500
# 13     0.472500
# 14     0.456667
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'Naive Bayes'
performance.iloc[i, 1] = 'LDA'

# %%
model = KNeighborsClassifier()

start_time = time.time()
model.fit(X_train_lda, y_train_encoded)

end_time = time.time()
performance.iloc[i, 2] = end_time - start_time

y_train_pred_3 = model.predict(X_train_lda)
y_val_pred_3 = model.predict(X_val_lda)

performance.iloc[i, 3] = accuracy_score(y_train_encoded, y_train_pred_3)
performance.iloc[i, 4] = accuracy_score(y_val_encoded, y_val_pred_3)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.566401      0.902500
# 1        XGBooster        Scaling           115.175411      1.000000
# 2    Random Forest        Scaling            48.204262      1.000000
# 3       AdaBooster        Scaling            52.048564      0.482083
# 4         Logistic        Scaling             0.567590      0.692708
# 5         Logistic            PCA             0.628999      0.692708
# 6         Logistic            LDA             0.607732      0.774167
# 7              SVM        Scaling             9.294330      0.999167
# 8              SVM            PCA             8.810364      0.822292
# 9              SVM            LDA             8.715013      0.536458
# 10             KNN        Scaling             0.019781      0.567083
# 11             KNN            PCA             0.020159      0.569792
# 12             KNN            LDA             0.018030      0.538750
# 13     Naive Bayes        Scaling             0.019555      0.638542
# 14     Naive Bayes            PCA             0.003792      0.635000
# 15     Naive Bayes            LDA             0.011261      0.751250
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.580833
# 1      0.576667
# 2      0.561667
# 3      0.449167
# 4      0.567500
# 5      0.567500
# 6      0.523333
# 7      0.615833
# 8      0.597500
# 9      0.478333
# 10     0.505000
# 11     0.500833
# 12     0.497500
# 13     0.472500
# 14     0.456667
# 15     0.535833
# 16          NaN

# %%
y_train_pred.append(y_train_pred_3)
y_val_pred.append(y_val_pred_3)

# %% [markdown]
# ## Voting
