# %% [markdown]
# # Combine all models
# MSc in Statistical Science\
# University of Oxford\
# Group-assessed practical\
# HT 2024

# %%
# Import libraries
import pandas as pd
import numpy as np
from search_param.grid_search import read_data, decode_dict
from fit_models import fit_model
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score
import shutil
import json
import time

# %% [markdown]
# ## Data processing

# %%
X_train, X_val, y_train, y_val = read_data()

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit label encoder and return encoded labels
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)

# Convert labels to one-hot encoding
y_train_onehot = to_categorical(y_train_encoded)
y_val_onehot = to_categorical(y_val_encoded)

# %%
# Standard scaling
scaler = StandardScaler()
scaler.fit(X_train)
X_train_sc = scaler.transform(X_train)
X_val_sc = scaler.transform(X_val)

# %%
# LDA
lda = LinearDiscriminantAnalysis(n_components=None)
X_train_lda = lda.fit_transform(X_train, y_train)
X_val_lda = lda.transform(X_val)

# %%
# PCA
p_PCA = 25 # from notebook pictures
pca = PCA(n_components=p_PCA, random_state=42)  # Select top 25 components
X_train_pca = pca.fit_transform(X_train_sc)
X_val_pca = pca.transform(X_val_sc)

# %% [markdown]
# ## Create dataframe

# %%
column_names = ['Model', 'Pre-processing', 'Training time (sec)', 'Training acc', 'Testing acc']

performance = pd.DataFrame({col: [np.nan] * 17 for col in column_names})
performance
# Out:
#     Model  Pre-processing  Training time (sec)  Training acc  Testing acc
# 0     NaN             NaN                  NaN           NaN          NaN
# 1     NaN             NaN                  NaN           NaN          NaN
# 2     NaN             NaN                  NaN           NaN          NaN
# 3     NaN             NaN                  NaN           NaN          NaN
# 4     NaN             NaN                  NaN           NaN          NaN
# 5     NaN             NaN                  NaN           NaN          NaN
# 6     NaN             NaN                  NaN           NaN          NaN
# 7     NaN             NaN                  NaN           NaN          NaN
# 8     NaN             NaN                  NaN           NaN          NaN
# 9     NaN             NaN                  NaN           NaN          NaN
# 10    NaN             NaN                  NaN           NaN          NaN
# 11    NaN             NaN                  NaN           NaN          NaN
# 12    NaN             NaN                  NaN           NaN          NaN
# 13    NaN             NaN                  NaN           NaN          NaN
# 14    NaN             NaN                  NaN           NaN          NaN
# 15    NaN             NaN                  NaN           NaN          NaN
# 16    NaN             NaN                  NaN           NaN          NaN

# %%
y_train_pred = []
y_val_pred = []

# %% [markdown]
# ## Neural Network

# %%
performance.iloc[0, 0] = 'Neural Network'
performance.iloc[0, 1] = 'Scaling'

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model

# %%
# Load JSON file into Python dictionary
with open('search_nn/sc_param.json', 'r') as f:
    config = json.load(f)

# %%
nn_model = Sequential.from_config(config)
nn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 320)            │       166,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 320)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 352)            │       112,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 352)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 480)            │       169,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 480)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8)              │         3,848 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 452,360 (1.73 MB)
#  Trainable params: 452,360 (1.73 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
nn_model.compile(optimizer="adam",
                 loss='categorical_crossentropy',  # Suitable for multi-class classification
                 metrics=['accuracy'])

# %%
start_time = time.time()

nn_model.fit(X_train_sc, y_train_onehot,
             validation_data=(X_val_sc, y_val_onehot),
             epochs=20)

end_time = time.time()
performance.iloc[0, 2] = end_time - start_time
# Out:
# Epoch 1/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.3309 - loss: 1.8774 - val_accuracy: 0.5092 - val_loss: 1.4400
# Epoch 2/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5009 - loss: 1.4016 - val_accuracy: 0.5408 - val_loss: 1.3491
# Epoch 3/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5593 - loss: 1.2493 - val_accuracy: 0.5600 - val_loss: 1.2915
# Epoch 4/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6065 - loss: 1.1124 - val_accuracy: 0.5742 - val_loss: 1.2681
# Epoch 5/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6295 - loss: 1.0629 - val_accuracy: 0.5742 - val_loss: 1.2962
# Epoch 6/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6703 - loss: 0.9550 - val_accuracy: 0.5792 - val_loss: 1.2599
# Epoch 7/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6835 - loss: 0.8912 - val_accuracy: 0.6092 - val_loss: 1.2537
# Epoch 8/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7187 - loss: 0.7960 - val_accuracy: 0.5975 - val_loss: 1.2628
# Epoch 9/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7236 - loss: 0.7881 - val_accuracy: 0.5883 - val_loss: 1.2861
# Epoch 10/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7535 - loss: 0.7093 - val_accuracy: 0.5967 - val_loss: 1.2990
# Epoch 11/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7487 - loss: 0.7020 - val_accuracy: 0.5825 - val_loss: 1.3705
# Epoch 12/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7777 - loss: 0.6344 - val_accuracy: 0.5833 - val_loss: 1.3654
# Epoch 13/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7796 - loss: 0.6320 - val_accuracy: 0.5908 - val_loss: 1.3743
# Epoch 14/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7949 - loss: 0.5964 - val_accuracy: 0.5933 - val_loss: 1.4134
# Epoch 15/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8140 - loss: 0.5304 - val_accuracy: 0.5975 - val_loss: 1.4084
# Epoch 16/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8170 - loss: 0.5124 - val_accuracy: 0.5742 - val_loss: 1.4814
# Epoch 17/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8345 - loss: 0.4752 - val_accuracy: 0.5867 - val_loss: 1.5295
# Epoch 18/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8433 - loss: 0.4614 - val_accuracy: 0.6008 - val_loss: 1.5123
# Epoch 19/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8436 - loss: 0.4372 - val_accuracy: 0.5742 - val_loss: 1.5856
# Epoch 20/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8615 - loss: 0.4135 - val_accuracy: 0.5942 - val_loss: 1.5618

# %%
y_train_pred.append(nn_model.predict(X_train_sc).argmax(axis=-1))
train_loss, performance.iloc[0, 3] = nn_model.evaluate(X_train_sc, y_train_onehot, verbose=0)
# Out:
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
y_val_pred.append(nn_model.predict(X_val_sc).argmax(axis=-1))
test_loss, performance.iloc[0, 4] = nn_model.evaluate(X_val_sc, y_val_onehot)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6137 - loss: 1.5140

# %%
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.514085       0.96875
# 1              NaN            NaN                  NaN           NaN
# 2              NaN            NaN                  NaN           NaN
# 3              NaN            NaN                  NaN           NaN
# 4              NaN            NaN                  NaN           NaN
# 5              NaN            NaN                  NaN           NaN
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.594167
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %% [markdown]
# ## XGB

# %%
performance.iloc[1, 0] = 'XGBooster'
performance.iloc[1, 1] = 'Scaling'

# %%
from xgboost import XGBClassifier

# %%
# Load JSON file into Python dictionary
with open('search_param/xgb_param.json', 'r') as f:
    param = json.load(f)

param['scaler'].popitem()
param = decode_dict(param['scaler'])

# %%
xgb_model = XGBClassifier(
    objective='multi:softmax',   # for multiclass classification
    num_class=8,                 # specify the number of classes
)
xgb_model.set_params(**param)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6000000000000001, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=17, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None, num_class=8,
#               num_parallel_tree=None, ...)

# %%
start_time = time.time()

xgb_model.fit(X_train_sc, y_train_encoded)

end_time = time.time()
performance.iloc[1, 2] = end_time - start_time

# %%
# Get train accuracy
performance.iloc[1, 3] = accuracy_score(y_train_encoded, xgb_model.predict(X_train_sc))

# Get test accuracy
performance.iloc[1, 4] = accuracy_score(y_val_encoded, xgb_model.predict(X_val_sc))

performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.343971      0.974583
# 1        XGBooster        Scaling           122.958627      1.000000
# 2              NaN            NaN                  NaN           NaN
# 3              NaN            NaN                  NaN           NaN
# 4              NaN            NaN                  NaN           NaN
# 5              NaN            NaN                  NaN           NaN
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.596667
# 1      0.576667
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN

# %% [markdown]
# ## Random Forest

# %%
performance.iloc[2, 0] = 'Random Forest'
performance.iloc[2, 1] = 'Scaling'

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Load JSON file into Python dictionary
with open('search_param/rf_param.json', 'r') as f:
    param = json.load(f)

param['scaler'].popitem()
param = decode_dict(param['scaler'])

# %%
rf_model = RandomForestClassifier()
rf_model.set_params(**param)
# Out:
# RandomForestClassifier(criterion='log_loss', max_depth=20, n_estimators=200)

# %%
start_time = time.time()

rf_model.fit(X_train_sc, y_train)

end_time = time.time()
performance.iloc[1, 2] = end_time - start_time

# %%
# Get train accuracy
performance.iloc[1, 3] = accuracy_score(y_train, rf_model.predict(X_train_sc))

# Get test accuracy
performance.iloc[1, 4] = accuracy_score(y_val, rf_model.predict(X_val_sc))

performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            17.343971      0.974583
# 1        XGBooster        Scaling            45.392582      1.000000
# 2    Random Forest        Scaling                  NaN           NaN
# 3              NaN            NaN                  NaN           NaN
# 4              NaN            NaN                  NaN           NaN
# 5              NaN            NaN                  NaN           NaN
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.596667
# 1      0.550000
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
