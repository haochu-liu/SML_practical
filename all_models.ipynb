# %% [markdown]
# # Combine all models
# MSc in Statistical Science\
# University of Oxford\
# Group-assessed practical\
# HT 2024

# %%
# Import libraries
import pandas as pd
import numpy as np
from search_param.grid_search import read_data, decode_dict
from fit_models import fit_model
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score
import shutil
import json
import time

# %% [markdown]
# ## Data processing

# %%
X_train, X_val, y_train, y_val = read_data()

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit label encoder and return encoded labels
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)

# Convert labels to one-hot encoding
y_train_onehot = to_categorical(y_train_encoded)
y_val_onehot = to_categorical(y_val_encoded)

# %%
# Standard scaling
scaler = StandardScaler()
scaler.fit(X_train)
X_train_sc = scaler.transform(X_train)
X_val_sc = scaler.transform(X_val)

# %%
# LDA
lda = LinearDiscriminantAnalysis(n_components=None)
X_train_lda = lda.fit_transform(X_train, y_train)
X_val_lda = lda.transform(X_val)

# %%
# PCA
p_PCA = 25 # from notebook pictures
pca = PCA(n_components=p_PCA, random_state=42)  # Select top 25 components
X_train_pca = pca.fit_transform(X_train_sc)
X_val_pca = pca.transform(X_val_sc)

# %% [markdown]
# ## Create dataframe

# %%
column_names = ['Model', 'Pre-processing', 'Training time (sec)', 'Training acc', 'Testing acc']

performance = pd.DataFrame({col: [np.nan] * 17 for col in column_names})
performance
# Out:
#     Model  Pre-processing  Training time (sec)  Training acc  Testing acc
# 0     NaN             NaN                  NaN           NaN          NaN
# 1     NaN             NaN                  NaN           NaN          NaN
# 2     NaN             NaN                  NaN           NaN          NaN
# 3     NaN             NaN                  NaN           NaN          NaN
# 4     NaN             NaN                  NaN           NaN          NaN
# 5     NaN             NaN                  NaN           NaN          NaN
# 6     NaN             NaN                  NaN           NaN          NaN
# 7     NaN             NaN                  NaN           NaN          NaN
# 8     NaN             NaN                  NaN           NaN          NaN
# 9     NaN             NaN                  NaN           NaN          NaN
# 10    NaN             NaN                  NaN           NaN          NaN
# 11    NaN             NaN                  NaN           NaN          NaN
# 12    NaN             NaN                  NaN           NaN          NaN
# 13    NaN             NaN                  NaN           NaN          NaN
# 14    NaN             NaN                  NaN           NaN          NaN
# 15    NaN             NaN                  NaN           NaN          NaN
# 16    NaN             NaN                  NaN           NaN          NaN

# %%
y_train_pred = []
y_val_pred = []

# %% [markdown]
# ## Neural Network

# %%
performance.iloc[0, 0] = 'Neural Network'
performance.iloc[0, 1] = 'Scaling'

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model

# %%
# Load JSON file into Python dictionary
with open('search_nn/sc_param.json', 'r') as f:
    config = json.load(f)

# %%
nn_model = Sequential.from_config(config)
nn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 480)            │       249,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 480)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 224)            │       107,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 224)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 288)            │        64,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 288)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8)              │         2,312 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 423,976 (1.62 MB)
#  Trainable params: 423,976 (1.62 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
nn_model.compile(optimizer="adam",
                 loss='categorical_crossentropy',  # Suitable for multi-class classification
                 metrics=['accuracy'])

# %%
start_time = time.time()

nn_model.fit(X_train_sc, y_train_onehot,
             validation_data=(X_val_sc, y_val_onehot),
             epochs=20)

end_time = time.time()
performance.iloc[0, 2] = end_time - start_time
# Out:
# Epoch 1/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.3086 - loss: 1.9313 - val_accuracy: 0.4675 - val_loss: 1.4540
# Epoch 2/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4994 - loss: 1.3809 - val_accuracy: 0.5358 - val_loss: 1.3157
# Epoch 3/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5657 - loss: 1.2397 - val_accuracy: 0.5592 - val_loss: 1.3178
# Epoch 4/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5535 - loss: 1.1999 - val_accuracy: 0.5725 - val_loss: 1.2600
# Epoch 5/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6077 - loss: 1.1031 - val_accuracy: 0.5658 - val_loss: 1.2766
# Epoch 6/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6337 - loss: 1.0520 - val_accuracy: 0.5900 - val_loss: 1.2259
# Epoch 7/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6236 - loss: 1.0328 - val_accuracy: 0.5942 - val_loss: 1.2357
# Epoch 8/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6731 - loss: 0.9598 - val_accuracy: 0.5933 - val_loss: 1.2501
# Epoch 9/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6734 - loss: 0.9268 - val_accuracy: 0.5783 - val_loss: 1.2615
# Epoch 10/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6925 - loss: 0.8746 - val_accuracy: 0.5825 - val_loss: 1.2815
# Epoch 11/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6871 - loss: 0.8782 - val_accuracy: 0.6050 - val_loss: 1.2494
# Epoch 12/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7137 - loss: 0.8021 - val_accuracy: 0.6075 - val_loss: 1.2281
# Epoch 13/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7290 - loss: 0.7788 - val_accuracy: 0.5942 - val_loss: 1.3180
# Epoch 14/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7265 - loss: 0.7661 - val_accuracy: 0.5958 - val_loss: 1.3075
# Epoch 15/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7444 - loss: 0.7421 - val_accuracy: 0.6058 - val_loss: 1.3139
# Epoch 16/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7469 - loss: 0.7236 - val_accuracy: 0.5875 - val_loss: 1.3128
# Epoch 17/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7517 - loss: 0.6938 - val_accuracy: 0.6058 - val_loss: 1.3651
# Epoch 18/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7781 - loss: 0.6383 - val_accuracy: 0.5900 - val_loss: 1.3734
# Epoch 19/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7913 - loss: 0.6050 - val_accuracy: 0.5900 - val_loss: 1.4658
# Epoch 20/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7874 - loss: 0.5988 - val_accuracy: 0.6058 - val_loss: 1.3854

# %%
y_train_pred.append(nn_model.predict(X_train_sc).argmax(axis=-1))
train_loss, performance.iloc[0, 3] = nn_model.evaluate(X_train_sc, y_train_onehot, verbose=0)
# Out:
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_val_pred.append(nn_model.predict(X_val_sc).argmax(axis=-1))
test_loss, performance.iloc[0, 4] = nn_model.evaluate(X_val_sc, y_val_onehot)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6377 - loss: 1.3422

# %%
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1              NaN            NaN                  NaN           NaN
# 2              NaN            NaN                  NaN           NaN
# 3              NaN            NaN                  NaN           NaN
# 4              NaN            NaN                  NaN           NaN
# 5              NaN            NaN                  NaN           NaN
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %% [markdown]
# ## XGB

# %%
i = 1
performance.iloc[i, 0] = 'XGBooster'
performance.iloc[i, 1] = 'Scaling'

# %%
from xgboost import XGBClassifier


model = XGBClassifier(
    objective='multi:softmax',   # for multiclass classification
    num_class=8,                 # specify the number of classes
)
performance.iloc[i, 2:5], y_train_pred_m, y_val_pred_m  = fit_model(model, 'search_param/xgb_param.json', 'scaler',
    X_train_sc, y_train_encoded, X_val_sc, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2              NaN            NaN                  NaN           NaN
# 3              NaN            NaN                  NaN           NaN
# 4              NaN            NaN                  NaN           NaN
# 5              NaN            NaN                  NaN           NaN
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
y_train_pred.append(y_train_pred_m)
y_val_pred.append(y_val_pred_m)

# %% [markdown]
# ## Random Forest

# %%
performance.iloc[i, 0] = 'Random Forest'
performance.iloc[i, 1] = 'Scaling'

# %%
from sklearn.ensemble import RandomForestClassifier


model = RandomForestClassifier()
performance.iloc[i, 2:5], y_train_pred_m, y_val_pred_m  = fit_model(model, 'search_param/rf_param.json', 'scaler',
    X_train_sc, y_train_encoded, X_val_sc, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2    Random Forest        Scaling            45.279888      1.000000
# 3              NaN            NaN                  NaN           NaN
# 4              NaN            NaN                  NaN           NaN
# 5              NaN            NaN                  NaN           NaN
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2      0.550000
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
y_train_pred.append(y_train_pred_m)
y_val_pred.append(y_val_pred_m)

# %% [markdown]
# ## AdaBooster

# %%
performance.iloc[i, 0] = 'AdaBooster'
performance.iloc[i, 1] = 'Scaling'

# %%
from sklearn.ensemble import AdaBoostClassifier


model = AdaBoostClassifier(random_state=42)
performance.iloc[i, 2:5], y_train_pred_m, y_val_pred_m  = fit_model(model, 'search_param/abc_param.json', 'scaler',
    X_train_sc, y_train_encoded, X_val_sc, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2    Random Forest        Scaling            45.279888      1.000000
# 3       AdaBooster        Scaling            47.811196      0.482083
# 4              NaN            NaN                  NaN           NaN
# 5              NaN            NaN                  NaN           NaN
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2      0.550000
# 3      0.449167
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
y_train_pred.append(y_train_pred_m)
y_val_pred.append(y_val_pred_m)

# %% [markdown]
# ## Logistic

# %%
performance.iloc[i, 0] = 'Logistic'
performance.iloc[i, 1] = 'Scaling'

# %%
from sklearn.linear_model import LogisticRegression


model = LogisticRegression()
performance.iloc[i, 2:5], y_train_pred_1, y_val_pred_1  = fit_model(model, 'search_param/logistic_param.json', 'scaler',
    X_train_sc, y_train_encoded, X_val_sc, y_val_encoded)

i += 1
performance
# Out:
# c:\Users\Liu_h\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2    Random Forest        Scaling            45.279888      1.000000
# 3       AdaBooster        Scaling            47.811196      0.482083
# 4         Logistic        Scaling             0.533180      0.692708
# 5              NaN            NaN                  NaN           NaN
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2      0.550000
# 3      0.449167
# 4      0.567500
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'Logistic'
performance.iloc[i, 1] = 'PCA'

# %%
model = LogisticRegression()
performance.iloc[i, 2:5], y_train_pred_2, y_val_pred_2  = fit_model(model, 'search_param/logistic_param.json', 'pca',
    X_train_pca, y_train_encoded, X_val_pca, y_val_encoded)

i += 1
performance
# Out:
# c:\Users\Liu_h\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2    Random Forest        Scaling            45.279888      1.000000
# 3       AdaBooster        Scaling            47.811196      0.482083
# 4         Logistic        Scaling             0.533180      0.692708
# 5         Logistic            PCA             0.103984      0.491875
# 6              NaN            NaN                  NaN           NaN
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2      0.550000
# 3      0.449167
# 4      0.567500
# 5      0.467500
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'Logistic'
performance.iloc[i, 1] = 'LDA'

# %%
model = LogisticRegression()
performance.iloc[i, 2:5], y_train_pred_3, y_val_pred_3  = fit_model(model, 'search_param/logistic_param.json', 'lda',
    X_train_lda, y_train_encoded, X_val_lda, y_val_encoded)

i += 1
performance
# Out:
# c:\Users\Liu_h\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1165: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2    Random Forest        Scaling            45.279888      1.000000
# 3       AdaBooster        Scaling            47.811196      0.482083
# 4         Logistic        Scaling             0.533180      0.692708
# 5         Logistic            PCA             0.103984      0.491875
# 6         Logistic            LDA             0.041544      0.707708
# 7              NaN            NaN                  NaN           NaN
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2      0.550000
# 3      0.449167
# 4      0.567500
# 5      0.467500
# 6      0.549167
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
y_train_pred.append(y_train_pred_1)
y_val_pred.append(y_val_pred_1)

# %% [markdown]
# ## SVM

# %%
performance.iloc[i, 0] = 'SVM'
performance.iloc[i, 1] = 'Scaling'

# %%
from sklearn.svm import SVC


model = SVC()
performance.iloc[i, 2:5], y_train_pred_1, y_val_pred_1  = fit_model(model, 'search_param/svm_param.json', 'scaler',
    X_train_sc, y_train_encoded, X_val_sc, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2    Random Forest        Scaling            45.279888      1.000000
# 3       AdaBooster        Scaling            47.811196      0.482083
# 4         Logistic        Scaling             0.533180      0.692708
# 5         Logistic            PCA             0.103984      0.491875
# 6         Logistic            LDA             0.041544      0.707708
# 7              SVM        Scaling             8.515433      0.999167
# 8              NaN            NaN                  NaN           NaN
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2      0.550000
# 3      0.449167
# 4      0.567500
# 5      0.467500
# 6      0.549167
# 7      0.615833
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'SVM'
performance.iloc[i, 1] = 'PCA'

# %%
model = SVC()
performance.iloc[i, 2:5], y_train_pred_2, y_val_pred_2  = fit_model(model, 'search_param/svm_param.json', 'pca',
    X_train_pca, y_train_encoded, X_val_pca, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2    Random Forest        Scaling            45.279888      1.000000
# 3       AdaBooster        Scaling            47.811196      0.482083
# 4         Logistic        Scaling             0.533180      0.692708
# 5         Logistic            PCA             0.103984      0.491875
# 6         Logistic            LDA             0.041544      0.707708
# 7              SVM        Scaling             8.515433      0.999167
# 8              SVM            PCA             1.244491      0.654375
# 9              NaN            NaN                  NaN           NaN
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2      0.550000
# 3      0.449167
# 4      0.567500
# 5      0.467500
# 6      0.549167
# 7      0.615833
# 8      0.534167
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'SVM'
performance.iloc[i, 1] = 'LDA'

# %%
model = SVC()
performance.iloc[i, 2:5], y_train_pred_3, y_val_pred_3  = fit_model(model, 'search_param/svm_param.json', 'lda',
    X_train_lda, y_train_encoded, X_val_lda, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2    Random Forest        Scaling            45.279888      1.000000
# 3       AdaBooster        Scaling            47.811196      0.482083
# 4         Logistic        Scaling             0.533180      0.692708
# 5         Logistic            PCA             0.103984      0.491875
# 6         Logistic            LDA             0.041544      0.707708
# 7              SVM        Scaling             8.515433      0.999167
# 8              SVM            PCA             1.244491      0.654375
# 9              SVM            LDA             0.803868      0.715208
# 10             NaN            NaN                  NaN           NaN
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2      0.550000
# 3      0.449167
# 4      0.567500
# 5      0.467500
# 6      0.549167
# 7      0.615833
# 8      0.534167
# 9      0.561667
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
y_train_pred.append(y_train_pred_1)
y_val_pred.append(y_val_pred_1)

# %% [markdown]
# ## KNN

# %%
performance.iloc[i, 0] = 'KNN'
performance.iloc[i, 1] = 'Scaling'

# %%
from sklearn.neighbors import KNeighborsClassifier


model = KNeighborsClassifier()
performance.iloc[i, 2:5], y_train_pred_1, y_val_pred_1  = fit_model(model, 'search_param/knn_param.json', 'scaler',
    X_train_sc, y_train_encoded, X_val_sc, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2    Random Forest        Scaling            45.279888      1.000000
# 3       AdaBooster        Scaling            47.811196      0.482083
# 4         Logistic        Scaling             0.533180      0.692708
# 5         Logistic            PCA             0.103984      0.491875
# 6         Logistic            LDA             0.041544      0.707708
# 7              SVM        Scaling             8.515433      0.999167
# 8              SVM            PCA             1.244491      0.654375
# 9              SVM            LDA             0.803868      0.715208
# 10             KNN        Scaling             0.016930      0.567083
# 11             NaN            NaN                  NaN           NaN
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2      0.550000
# 3      0.449167
# 4      0.567500
# 5      0.467500
# 6      0.549167
# 7      0.615833
# 8      0.534167
# 9      0.561667
# 10     0.505000
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'KNN'
performance.iloc[i, 1] = 'PCA'

# %%
model = KNeighborsClassifier()
performance.iloc[i, 2:5], y_train_pred_2, y_val_pred_2  = fit_model(model, 'search_param/knn_param.json', 'pca',
    X_train_pca, y_train_encoded, X_val_pca, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2    Random Forest        Scaling            45.279888      1.000000
# 3       AdaBooster        Scaling            47.811196      0.482083
# 4         Logistic        Scaling             0.533180      0.692708
# 5         Logistic            PCA             0.103984      0.491875
# 6         Logistic            LDA             0.041544      0.707708
# 7              SVM        Scaling             8.515433      0.999167
# 8              SVM            PCA             1.244491      0.654375
# 9              SVM            LDA             0.803868      0.715208
# 10             KNN        Scaling             0.016930      0.567083
# 11             KNN            PCA             0.001508      0.533333
# 12             NaN            NaN                  NaN           NaN
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2      0.550000
# 3      0.449167
# 4      0.567500
# 5      0.467500
# 6      0.549167
# 7      0.615833
# 8      0.534167
# 9      0.561667
# 10     0.505000
# 11     0.471667
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'KNN'
performance.iloc[i, 1] = 'LDA'

# %%
model = KNeighborsClassifier()
performance.iloc[i, 2:5], y_train_pred_3, y_val_pred_3  = fit_model(model, 'search_param/knn_param.json', 'lda',
    X_train_lda, y_train_encoded, X_val_lda, y_val_encoded)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2    Random Forest        Scaling            45.279888      1.000000
# 3       AdaBooster        Scaling            47.811196      0.482083
# 4         Logistic        Scaling             0.533180      0.692708
# 5         Logistic            PCA             0.103984      0.491875
# 6         Logistic            LDA             0.041544      0.707708
# 7              SVM        Scaling             8.515433      0.999167
# 8              SVM            PCA             1.244491      0.654375
# 9              SVM            LDA             0.803868      0.715208
# 10             KNN        Scaling             0.016930      0.567083
# 11             KNN            PCA             0.001508      0.533333
# 12             KNN            LDA             0.000986      0.712917
# 13             NaN            NaN                  NaN           NaN
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2      0.550000
# 3      0.449167
# 4      0.567500
# 5      0.467500
# 6      0.549167
# 7      0.615833
# 8      0.534167
# 9      0.561667
# 10     0.505000
# 11     0.471667
# 12     0.554167
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN

# %%
y_train_pred.append(y_train_pred_3)
y_val_pred.append(y_val_pred_3)

# %% [markdown]
# ## Naive Bayes

# %%
performance.iloc[i, 0] = 'Naive Bayes'
performance.iloc[i, 1] = 'Scaling'

# %%
from sklearn.neighbors import KNeighborsClassifier


model = KNeighborsClassifier()

start_time = time.time()
model.fit(X_train_sc, y_train_encoded)

end_time = time.time()
performance.iloc[i, 2] = end_time - start_time

y_train_pred_1 = model.predict(X_train_sc)
y_val_pred_1 = model.predict(X_val_sc)

performance.iloc[i, 3] = accuracy_score(y_train_encoded, y_train_pred_1)
performance.iloc[i, 4] = accuracy_score(y_val_encoded, y_val_pred_1)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2    Random Forest        Scaling            45.279888      1.000000
# 3       AdaBooster        Scaling            47.811196      0.482083
# 4         Logistic        Scaling             0.533180      0.692708
# 5         Logistic            PCA             0.103984      0.491875
# 6         Logistic            LDA             0.041544      0.707708
# 7              SVM        Scaling             8.515433      0.999167
# 8              SVM            PCA             1.244491      0.654375
# 9              SVM            LDA             0.803868      0.715208
# 10             KNN        Scaling             0.016930      0.567083
# 11             KNN            PCA             0.001508      0.533333
# 12             KNN            LDA             0.000986      0.712917
# 13     Naive Bayes        Scaling             0.014810      0.638542
# 14             NaN            NaN                  NaN           NaN
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2      0.550000
# 3      0.449167
# 4      0.567500
# 5      0.467500
# 6      0.549167
# 7      0.615833
# 8      0.534167
# 9      0.561667
# 10     0.505000
# 11     0.471667
# 12     0.554167
# 13     0.472500
# 14          NaN
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'Naive Bayes'
performance.iloc[i, 1] = 'PCA'

# %%
model = KNeighborsClassifier()

start_time = time.time()
model.fit(X_train_pca, y_train_encoded)

end_time = time.time()
performance.iloc[i, 2] = end_time - start_time

y_train_pred_2 = model.predict(X_train_pca)
y_val_pred_2 = model.predict(X_val_pca)

performance.iloc[i, 3] = accuracy_score(y_train_encoded, y_train_pred_2)
performance.iloc[i, 4] = accuracy_score(y_val_encoded, y_val_pred_2)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2    Random Forest        Scaling            45.279888      1.000000
# 3       AdaBooster        Scaling            47.811196      0.482083
# 4         Logistic        Scaling             0.533180      0.692708
# 5         Logistic            PCA             0.103984      0.491875
# 6         Logistic            LDA             0.041544      0.707708
# 7              SVM        Scaling             8.515433      0.999167
# 8              SVM            PCA             1.244491      0.654375
# 9              SVM            LDA             0.803868      0.715208
# 10             KNN        Scaling             0.016930      0.567083
# 11             KNN            PCA             0.001508      0.533333
# 12             KNN            LDA             0.000986      0.712917
# 13     Naive Bayes        Scaling             0.014810      0.638542
# 14     Naive Bayes            PCA             0.005474      0.635000
# 15             NaN            NaN                  NaN           NaN
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2      0.550000
# 3      0.449167
# 4      0.567500
# 5      0.467500
# 6      0.549167
# 7      0.615833
# 8      0.534167
# 9      0.561667
# 10     0.505000
# 11     0.471667
# 12     0.554167
# 13     0.472500
# 14     0.456667
# 15          NaN
# 16          NaN

# %%
performance.iloc[i, 0] = 'Naive Bayes'
performance.iloc[i, 1] = 'LDA'

# %%
model = KNeighborsClassifier()

start_time = time.time()
model.fit(X_train_lda, y_train_encoded)

end_time = time.time()
performance.iloc[i, 2] = end_time - start_time

y_train_pred_3 = model.predict(X_train_lda)
y_val_pred_3 = model.predict(X_val_lda)

performance.iloc[i, 3] = accuracy_score(y_train_encoded, y_train_pred_3)
performance.iloc[i, 4] = accuracy_score(y_val_encoded, y_val_pred_3)

i += 1
performance
# Out:
#              Model Pre-processing  Training time (sec)  Training acc  \
# 0   Neural Network        Scaling            18.737374      0.900417
# 1        XGBooster        Scaling           114.592163      1.000000
# 2    Random Forest        Scaling            45.279888      1.000000
# 3       AdaBooster        Scaling            47.811196      0.482083
# 4         Logistic        Scaling             0.533180      0.692708
# 5         Logistic            PCA             0.103984      0.491875
# 6         Logistic            LDA             0.041544      0.707708
# 7              SVM        Scaling             8.515433      0.999167
# 8              SVM            PCA             1.244491      0.654375
# 9              SVM            LDA             0.803868      0.715208
# 10             KNN        Scaling             0.016930      0.567083
# 11             KNN            PCA             0.001508      0.533333
# 12             KNN            LDA             0.000986      0.712917
# 13     Naive Bayes        Scaling             0.014810      0.638542
# 14     Naive Bayes            PCA             0.005474      0.635000
# 15     Naive Bayes            LDA             0.009152      0.751250
# 16             NaN            NaN                  NaN           NaN
#
#     Testing acc
# 0      0.605833
# 1      0.576667
# 2      0.550000
# 3      0.449167
# 4      0.567500
# 5      0.467500
# 6      0.549167
# 7      0.615833
# 8      0.534167
# 9      0.561667
# 10     0.505000
# 11     0.471667
# 12     0.554167
# 13     0.472500
# 14     0.456667
# 15     0.535833
# 16          NaN

# %%
y_train_pred.append(y_train_pred_3)
y_val_pred.append(y_val_pred_3)

# %% [markdown]
# ## Voting

# %%
from scipy.stats import mode


y_train_vote, _ = mode(np.array(y_train_pred), axis=0)
y_val_vote, _ = mode(np.array(y_val_pred), axis=0)

# %%
accuracy_score(y_train_encoded, y_train_vote)
# Out:
# 0.92875

# %%
accuracy_score(y_val_encoded, y_val_vote)
# Out:
# 0.6083333333333333
