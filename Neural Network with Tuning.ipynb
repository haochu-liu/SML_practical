# %% [markdown]
# # Sample Python Code
# MSc in Statistical Science\
# University of Oxford\
# Group-assessed practical\
# HT 2024

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ## Load dataset

# %%
# Load the training data and the test inputs
X_train = pd.read_csv('/Users/chenyuxing/Downloads/乐乐的文件/X_train.csv', index_col = 0, header=[0, 1, 2]) # inputs of the training set
y_train = pd.read_csv('/Users/chenyuxing/Downloads/乐乐的文件/y_train.csv', index_col = 0).to_numpy() # outputs of the training set
X_test =  pd.read_csv('/Users/chenyuxing/Downloads/乐乐的文件/X_test.csv', index_col = 0, header=[0, 1, 2]) # inputs of the test set

# %%
# X_train is a 6,000 * 518 dataframe.
# Entries (i,j) correspond to the j'th dimension of the observation i
X_train
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# Id
# 0            -0.266585 -0.984668 -0.729823 -0.895122  2.138628  0.935209
# 1            -0.180061  0.260884 -0.069373  0.208734 -0.078855 -0.577818
# 2            -0.692900  0.356662  0.062617  0.248280  3.470037  0.166613
# 3             0.243339  0.214182 -0.049026  1.456255 -0.360826 -0.875256
# 4            -0.968576  0.309255  0.223164  0.160960  0.919838 -0.111985
# ...                ...       ...       ...       ...       ...       ...
# 5995          0.503490 -0.540720 -0.690117 -0.107338 -0.647856 -0.681969
# 5996         -0.600597  0.406386 -0.748409 -0.316157 -0.507428 -0.054214
# 5997         -1.014298 -0.950744  0.618304  0.204298 -0.788411 -0.794254
# 5998         -0.002938  0.646034 -0.732819  1.205990 -0.898733 -0.684953
# 5999         -0.881917 -0.615638  0.891155  4.850262 -0.349280 -1.010980
#
# feature                                             ...   tonnetz            \
# statistics                                          ...       std
# number            07        08        09        10  ...        04        05
# Id                                                  ...
# 0           0.104089 -0.698659 -0.736408 -0.334376  ...  0.065003  0.016522
# 1           0.583788  0.143781  0.291556  0.007314  ...  0.087692  0.016355
# 2           0.823874  0.181112  0.551939  0.357985  ...  0.132387  0.025847
# 3          -0.770200  0.315500  0.789956  0.448319  ...  0.071478  0.019166
# 4          -1.012521 -0.665692 -0.316646 -0.264381  ...  0.106220  0.023536
# ...              ...       ...       ...       ...  ...       ...       ...
# 5995       -0.246245 -0.546552  0.062783  0.070393  ...  0.084929  0.017250
# 5996       -0.476804 -0.373120 -0.930158 -1.080690  ...  0.075407  0.014998
# 5997       -0.586847  0.099172 -0.313476 -0.523417  ...  0.138591  0.024969
# 5998        0.134642 -0.374792 -0.019524 -1.016032  ...  0.137695  0.030371
# 5999       -0.577905 -0.046604 -0.828026 -0.457468  ...  0.175120  0.039703
#
# feature                      zcr                                          \
# statistics              kurtosis       max      mean    median       min
# number            06          01        01        01        01        01
# Id
# 0           0.015776    5.743597  0.307617  0.051370  0.042480  0.002441
# 1           0.016605   64.870987  0.812988  0.082784  0.069824  0.003906
# 2           0.023922   34.251705  0.850098  0.058200  0.036621  0.010254
# 3           0.025535    1.364990  0.342285  0.081713  0.075195  0.000000
# 4           0.019742    3.589230  0.322266  0.073736  0.069336  0.004395
# ...              ...         ...       ...       ...       ...       ...
# 5995        0.020335    4.868783  0.668945  0.076452  0.044434  0.001465
# 5996        0.020683    7.893681  0.584961  0.076210  0.048340  0.000000
# 5997        0.023658   27.257378  0.373047  0.042598  0.037598  0.000000
# 5998        0.029970  431.200500  0.384277  0.025731  0.025391  0.008301
# 5999        0.025094   13.567758  0.233398  0.047689  0.044922  0.015625
#
# feature
# statistics       skew       std
# number             01        01
# Id
# 0            1.976972  0.034533
# 1            7.374503  0.074870
# 2            5.927942  0.117603
# 3            1.100437  0.041754
# 4            1.210593  0.036459
# ...               ...       ...
# 5995         2.045856  0.084214
# 5996         2.561808  0.073010
# 5997         3.778109  0.027813
# 5998        10.260160  0.006870
# 5999         2.553229  0.018049
#
# [6000 rows x 518 columns]

# %%
number_classes=np.unique(y_train)
len(number_classes)
# Out:
# 8

# %%
#y_train contains the true class:  Electronic, Experimental, Folk, Hip-Hop, Instrumental, International, Pop or Rock
y_train.ravel()
# Out:
# array(['Electronic', 'Rock', 'Instrumental', ..., 'Pop', 'Instrumental',
#        'Instrumental'], dtype=object)

# %%
# X_test is the array of test inputs, of the same format as X_train. The objective is to predict the class (Electronic, Experimental, Folk, Hip-Hop, Instrumental, International, Pop or Rock) of the output
X_test
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# Id
# 0             3.974762  4.354650  3.394523  0.033462  5.611623  2.592655
# 1             0.033636 -0.139950  0.678688 -0.553824 -0.165293  0.370275
# 2             0.044094  4.285359  0.977213  3.240997  0.400350  1.026224
# 3            -0.425218  0.793007  0.509624 -0.967103 -1.432252 -0.900761
# 4            -1.120238 -0.503659  0.303515 -0.596549 -0.716761 -0.874363
# ...                ...       ...       ...       ...       ...       ...
# 1995         -0.166039 -0.660406 -0.955245 -0.689303 -0.916851 -0.136661
# 1996          2.010343  0.344572  2.738141  1.238262  2.815471  0.689118
# 1997         -0.869148 -0.600280  0.105814  0.553810 -0.839182 -0.706434
# 1998         -0.854251 -0.804227  1.347275 -0.748155 -0.408385 -0.909165
# 1999          0.929528  0.922116  1.074849  0.431512  0.040441 -0.361733
#
# feature                                             ...   tonnetz            \
# statistics                                          ...       std
# number            07        08        09        10  ...        04        05
# Id                                                  ...
# 0           3.041094  2.815378  3.954026  2.365586  ...  0.052970  0.013487
# 1          -0.314710 -0.368706 -0.437181 -0.441662  ...  0.093105  0.022865
# 2           0.772464  0.807625  1.942534  1.938970  ...  0.081955  0.017371
# 3          -0.501279 -0.855886 -0.556825  7.404243  ...  0.098877  0.019089
# 4          -0.708101 -0.642351 -0.327327 -0.342220  ...  0.102545  0.023823
# ...              ...       ...       ...       ...  ...       ...       ...
# 1995       -0.367279 -1.135291 -1.174082 -0.609749  ...  0.060857  0.022777
# 1996        4.040531  2.749969  2.658481  4.763800  ...  0.050589  0.015169
# 1997       -0.360566  0.053638 -0.791513 -0.669329  ...  0.079556  0.025229
# 1998       -0.870467 -0.077660 -0.538250 -0.108390  ...  0.147899  0.023989
# 1999        0.371801  0.470401 -0.566806  0.082485  ...  0.119940  0.023605
#
# feature                     zcr                                          \
# statistics             kurtosis       max      mean    median       min
# number            06         01        01        01        01        01
# Id
# 0           0.022031  70.844788  0.671387  0.035129  0.026367  0.010254
# 1           0.028800  18.427612  0.538574  0.055975  0.039062  0.000000
# 2           0.016673  38.401405  0.405762  0.030685  0.028809  0.002930
# 3           0.016183   4.129582  0.252441  0.037955  0.024902  0.000000
# 4           0.025166  16.758356  0.380371  0.027851  0.019043  0.000000
# ...              ...        ...       ...       ...       ...       ...
# 1995        0.017722   8.467750  0.444824  0.055770  0.039062  0.001465
# 1996        0.013096  -0.649581  0.357422  0.126850  0.120117  0.000000
# 1997        0.026858   1.563682  0.152344  0.039138  0.035156  0.002441
# 1998        0.027429  22.050222  0.319824  0.032715  0.028809  0.000000
# 1999        0.024036   2.444547  0.256836  0.047209  0.041016  0.002441
#
# feature
# statistics      skew       std
# number            01        01
# Id
# 0           8.394708  0.067026
# 1           3.638194  0.053879
# 2           2.620369  0.016835
# 3           1.898847  0.034382
# 4           3.244483  0.027128
# ...              ...       ...
# 1995        2.520271  0.056601
# 1996        0.234551  0.055476
# 1997        1.084503  0.020284
# 1998        3.429668  0.022654
# 1999        1.266626  0.030202
#
# [2000 rows x 518 columns]

# %% [markdown]
# ## Neural Network

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit label encoder and return encoded labels
y_train_encoded = label_encoder.fit_transform(y_train)

# Now y_train_encoded contains integers representing the categories
# Out:
# /Users/chenyuxing/opt/anaconda3/envs/py37torch131/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_train)

# Convert labels to one-hot encoding
y_onehot = to_categorical(y_train_encoded)

# Split the dataset into training and validation sets
X_training, X_val, y_training, y_val = train_test_split(X_scaled, y_onehot, test_size=0.2, random_state=42)

# %% [markdown]
# # Try a NN model first

# %%
model = Sequential([
    Dense(512, activation='relu', input_shape=(518,)),  # Adjust input_shape based on your feature count
    Dropout(0.5),  # Helps prevent overfitting
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dense(8, activation='softmax')  # Output layer: one neuron per class, softmax for multi-class classification
])

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',  # Suitable for multi-class classification
              metrics=['accuracy'])

# %%
history = model.fit(X_training, y_training,
                    validation_data=(X_val, y_val),
                    epochs=30,
                    batch_size=64)  # Tune based on your hardware capabilities
# Out:
# Epoch 1/30
# 2024-03-10 14:14:41.741248: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 75/75 [==============================] - 1s 4ms/step - loss: 2.1078 - accuracy: 0.1831 - val_loss: 1.8798 - val_accuracy: 0.2808
# Epoch 2/30
# 75/75 [==============================] - 0s 4ms/step - loss: 1.8765 - accuracy: 0.2635 - val_loss: 1.7509 - val_accuracy: 0.3717
# Epoch 3/30
# 75/75 [==============================] - 0s 6ms/step - loss: 1.7745 - accuracy: 0.3285 - val_loss: 1.6507 - val_accuracy: 0.4167
# Epoch 4/30
# 75/75 [==============================] - 0s 4ms/step - loss: 1.6371 - accuracy: 0.3898 - val_loss: 1.5464 - val_accuracy: 0.4533
# Epoch 5/30
# 75/75 [==============================] - 0s 6ms/step - loss: 1.5641 - accuracy: 0.4208 - val_loss: 1.4605 - val_accuracy: 0.5225
# Epoch 6/30
# 75/75 [==============================] - 0s 6ms/step - loss: 1.4989 - accuracy: 0.4690 - val_loss: 1.4499 - val_accuracy: 0.5133
# Epoch 7/30
# 75/75 [==============================] - 0s 6ms/step - loss: 1.4478 - accuracy: 0.4829 - val_loss: 1.4118 - val_accuracy: 0.5408
# Epoch 8/30
# 75/75 [==============================] - 0s 5ms/step - loss: 1.3748 - accuracy: 0.5135 - val_loss: 1.3653 - val_accuracy: 0.5508
# Epoch 9/30
# 75/75 [==============================] - 0s 4ms/step - loss: 1.3499 - accuracy: 0.5327 - val_loss: 1.3536 - val_accuracy: 0.5417
# Epoch 10/30
# 75/75 [==============================] - 0s 6ms/step - loss: 1.3006 - accuracy: 0.5485 - val_loss: 1.3488 - val_accuracy: 0.5542
# Epoch 11/30
# 75/75 [==============================] - 0s 5ms/step - loss: 1.2642 - accuracy: 0.5704 - val_loss: 1.3289 - val_accuracy: 0.5617
# Epoch 12/30
# 75/75 [==============================] - 0s 5ms/step - loss: 1.2393 - accuracy: 0.5825 - val_loss: 1.3325 - val_accuracy: 0.5642
# Epoch 13/30
# 75/75 [==============================] - 1s 9ms/step - loss: 1.2252 - accuracy: 0.5785 - val_loss: 1.3196 - val_accuracy: 0.5642
# Epoch 14/30
# 75/75 [==============================] - 0s 5ms/step - loss: 1.1995 - accuracy: 0.5875 - val_loss: 1.3296 - val_accuracy: 0.5658
# Epoch 15/30
# 75/75 [==============================] - 0s 5ms/step - loss: 1.1581 - accuracy: 0.6083 - val_loss: 1.3057 - val_accuracy: 0.5750
# Epoch 16/30
# 75/75 [==============================] - 0s 4ms/step - loss: 1.1273 - accuracy: 0.6110 - val_loss: 1.3124 - val_accuracy: 0.5667
# Epoch 17/30
# 75/75 [==============================] - 0s 4ms/step - loss: 1.0917 - accuracy: 0.6285 - val_loss: 1.2921 - val_accuracy: 0.5783
# Epoch 18/30
# 75/75 [==============================] - 0s 5ms/step - loss: 1.0688 - accuracy: 0.6379 - val_loss: 1.3085 - val_accuracy: 0.5742
# Epoch 19/30
# 75/75 [==============================] - 0s 4ms/step - loss: 1.0696 - accuracy: 0.6417 - val_loss: 1.2963 - val_accuracy: 0.5750
# Epoch 20/30
# 75/75 [==============================] - 0s 4ms/step - loss: 1.0337 - accuracy: 0.6569 - val_loss: 1.3012 - val_accuracy: 0.5808
# Epoch 21/30
# 75/75 [==============================] - 0s 4ms/step - loss: 1.0294 - accuracy: 0.6581 - val_loss: 1.3183 - val_accuracy: 0.5833
# Epoch 22/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.9823 - accuracy: 0.6654 - val_loss: 1.2843 - val_accuracy: 0.5850
# Epoch 23/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.9651 - accuracy: 0.6781 - val_loss: 1.2997 - val_accuracy: 0.5867
# Epoch 24/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.9271 - accuracy: 0.6846 - val_loss: 1.2790 - val_accuracy: 0.5817
# Epoch 25/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.9416 - accuracy: 0.6877 - val_loss: 1.2826 - val_accuracy: 0.5875
# Epoch 26/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.9098 - accuracy: 0.6933 - val_loss: 1.3167 - val_accuracy: 0.5792
# Epoch 27/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.9047 - accuracy: 0.7013 - val_loss: 1.3071 - val_accuracy: 0.5892
# Epoch 28/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.8903 - accuracy: 0.7042 - val_loss: 1.2994 - val_accuracy: 0.5967
# Epoch 29/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.8681 - accuracy: 0.7127 - val_loss: 1.2612 - val_accuracy: 0.5767
# Epoch 30/30
# 75/75 [==============================] - 0s 4ms/step - loss: 0.8139 - accuracy: 0.7252 - val_loss: 1.3219 - val_accuracy: 0.5875

# %%
# predict the y labels for X_test
y_pred=model.predict(X_test)
# Out:
# 63/63 [==============================] - 0s 783us/step

# %% [markdown]
# ## NN tuning parameters

# %%
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model

def create_model(n_layers=3, activation='relu',leanring_rate=0.01,dropout=0.5):
    inputs = Input(shape=(518,))
    x = inputs
    for _ in range(n_layers):
        x = Dense(256, activation=activation)(x)
        x = Dropout(dropout)(x)
    outputs = Dense(8, activation='softmax')(x)  # Assuming 8 classes
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=Adam(learning_rate=leanring_rate),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
from sklearn.model_selection import KFold

n_splits = 5  # For example, 5-fold cross-validation
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# %%
# !pip install -U keras-tuner
from kerastuner import RandomSearch
# Out:
# Requirement already satisfied: keras-tuner in /Users/chenyuxing/opt/anaconda3/envs/py37torch131/lib/python3.9/site-packages (1.4.6)
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /Users/chenyuxing/opt/anaconda3/envs/py37torch131/lib/python3.9/site-packages (from keras-tuner) (2.11.0)
# Requirement already satisfied: packaging in /Users/chenyuxing/opt/anaconda3/envs/py37torch131/lib/python3.9/site-packages (from keras-tuner) (23.1)
# Requirement already satisfied: requests in /Users/chenyuxing/opt/anaconda3/envs/py37torch131/lib/python3.9/site-packages (from keras-tuner) (2.31.0)
# Requirement already satisfied: kt-legacy in /Users/chenyuxing/opt/anaconda3/envs/py37torch131/lib/python3.9/site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/chenyuxing/opt/anaconda3/envs/py37torch131/lib/python3.9/site-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chenyuxing/opt/anaconda3/envs/py37torch131/lib/python3.9/site-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/chenyuxing/opt/anaconda3/envs/py37torch131/lib/python3.9/site-packages (from requests->keras-tuner) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chenyuxing/opt/anaconda3/envs/py37torch131/lib/python3.9/site-packages (from requests->keras-tuner) (2024.2.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.5 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: keras-tuner
#   Attempting uninstall: keras-tuner
#     Found existing installation: keras-tuner 1.4.6
#     Uninstalling keras-tuner-1.4.6:
#       Successfully uninstalled keras-tuner-1.4.6
# Successfully installed keras-tuner-1.4.7
# /var/folders/qy/98h7cfd176d60r3ydhylc84c0000gn/T/ipykernel_74037/722794956.py:2: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner import RandomSearch

# %% [markdown]
# ### Tuning hyperparameter to find the optimal NN

# %%
def build_model(hp):
    model = Sequential()
    model.add(Dense(units=hp.Int('units', min_value=32, max_value=518, step=32),
                    activation=hp.Choice('activation', values=['relu', 'softplus', 'tanh', 'sigmoid']),
                    input_shape=(518,)))  # Ensure this matches your feature size
    # Use hp.Choice to select the dropout rate
    model.add(Dropout(rate=hp.Choice('dropout_0', values=[0.25, 0.5])))

    for i in range(hp.Int('layers', 1, 5)):
        model.add(Dense(units=hp.Int(f'units_{i}', min_value=32, max_value=518, step=32),
                        activation=hp.Choice(f'activation_{i}', values=['relu', 'softplus', 'tanh', 'sigmoid'])))
        # Use hp.Choice for each layer's dropout rate
        model.add(Dropout(rate=hp.Choice(f'dropout_{i+1}', values=[0.25, 0.5])))

    model.add(Dense(8, activation='softmax'))  # Adjust the number of units based on your number of classes
    model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])
    return model


tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,  # Set smaller during experimentation
    executions_per_trial=1,  # Increase for more robust results
    directory='my_dir',
    project_name='hparam_tuning'
)

tuner.search(X_training, y_training, epochs=20, validation_data=(X_val, y_val))  # Use a lower number of epochs for the search phase
# Out:
# Trial 5 Complete [00h 00m 10s]
# val_accuracy: 0.6175000071525574
#
# Best val_accuracy So Far: 0.6299999952316284
# Total elapsed time: 00h 00m 47s

# %%
# Get the best model
best_model = tuner.get_best_models(num_models=1)[0]
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 416)               215904
#
#  dropout (Dropout)           (None, 416)               0
#
#  dense_1 (Dense)             (None, 480)               200160
#
#  dropout_1 (Dropout)         (None, 480)               0
#
#  dense_2 (Dense)             (None, 224)               107744
#
#  dropout_2 (Dropout)         (None, 224)               0
#
#  dense_3 (Dense)             (None, 352)               79200
#
#  dropout_3 (Dropout)         (None, 352)               0
#
#  dense_4 (Dense)             (None, 352)               124256
#
#  dropout_4 (Dropout)         (None, 352)               0
#
#  dense_5 (Dense)             (None, 8)                 2824
#
# =================================================================
# Total params: 730,088
# Trainable params: 730,088
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Save the best model to a file
best_model.save('best_model.h5')

# %%
for layer in best_model.layers:
    config = layer.get_config()  # Get the layer's configuration dict
    # The 'activation' key in the config dict contains the activation function name
    if 'activation' in config:
        print(f"Layer: {layer.name}, Activation Function: {config['activation']}")
    else:
        print(f"Layer: {layer.name}, No activation function")
# Out:
# Layer: dense, Activation Function: tanh
# Layer: dropout, No activation function
# Layer: dense_1, Activation Function: tanh
# Layer: dropout_1, No activation function
# Layer: dense_2, Activation Function: relu
# Layer: dropout_2, No activation function
# Layer: dense_3, Activation Function: relu
# Layer: dropout_3, No activation function
# Layer: dense_4, Activation Function: sigmoid
# Layer: dropout_4, No activation function
# Layer: dense_5, Activation Function: softmax

# %% [markdown]
# ## Classification with knn and prediction on the test set

# %%
# Example with a k-nearest neighbours classifier
clf = KNeighborsClassifier(n_neighbors = 5)
clf.fit(X_train, y_train)
print('Accuracy of 5-nn on the training set: ', clf.score(X_train, y_train)) # evaluate the accuracy on the training set
# Out:
# Accuracy of 5-nn on the training set:  0.5468333333333333

# %%
y_pred = clf.predict(X_test) # compute knn predictions on the test inputs
y_pred
# Out:
# array(['Folk', 'Hip-Hop', 'International', ..., 'Experimental', 'Pop',
#        'Folk'], dtype=object)

# %% [markdown]
# ## Export in csv format

# %%
# Export the predictions on the test data in csv format
prediction = pd.DataFrame(y_pred, columns=['Genre'])
prediction.index.name='Id'
prediction.to_csv('myprediction.csv') # export to csv file

# The csv file should be of the form
#Id, Genre
#0, Folk
#1, Hip-Hop
#2, International
#...
#1998, Experimental
#1999, Pop
